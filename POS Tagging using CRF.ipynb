# %%
from itertools import chain

import nltk
import sklearn
import scipy.stats
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RandomizedSearchCV

import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics

import io
from io import open
from conllu import parse

import warnings
warnings.filterwarnings("ignore")

# %%
train_data_file = open('hi-ud-train.conllu', mode = 'rt', encoding = 'utf-8')
train_data = train_data_file.read()
train_data = train_data.replace(',', '  ')
train_sents = parse(train_data, fields = ['ID', 'WORD', 'POS_TAG'])

test_data_file = open('hi-ud-test .conllu', mode = 'rt', encoding = 'utf-8')
test_data = test_data_file.read()
test_data = test_data.replace('TAG', 'POS_TAG')
test_sents = parse(test_data, fields = ['ID', 'WORD', 'POS_TAG'])

for i in range(len(train_sents[0])):
    if train_sents[0][i]['WORD']=='COMMA':
        train_sents[0][i]['WORD']=','
        train_sents[0][i]['POS_TAG']='PUNCT'
        
for i in range(len(test_sents[0])):
    if test_sents[0][i]['WORD']=='COMMA':
        test_sents[0][i]['WORD']=','
        test_sents[0][i]['POS_TAG']='PUNCT'
        
print('\n******* Training data **********\n')
for i in range(len(train_sents[0])):
    print(train_sents[0][i])

print('\n******* Test data *************\n')
for i in range(len(test_sents[0])):
    print(test_sents[0][i])
# Out:
# ******* Training data **********
#
# {'ID': 'ID', 'WORD': 'WORD', 'POS_TAG': 'POS_TAG'}
# {'ID': '1', 'WORD': 'yaha', 'POS_TAG': 'DET'}
# {'ID': '2', 'WORD': 'eSiyA', 'POS_TAG': 'PROPN'}
# {'ID': '3', 'WORD': 'kI', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'sabase', 'POS_TAG': 'ADV'}
# {'ID': '5', 'WORD': 'badZI', 'POS_TAG': 'ADJ'}
# {'ID': '6', 'WORD': 'masjixoM', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '8', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '9', 'WORD': 'eka', 'POS_TAG': 'NUM'}
# {'ID': '10', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '11', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'ise', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'navAba', 'POS_TAG': 'NOUN'}
# {'ID': '3', 'WORD': 'SAhajehana', 'POS_TAG': 'PROPN'}
# {'ID': '4', 'WORD': 'ne', 'POS_TAG': 'ADP'}
# {'ID': '5', 'WORD': 'banavAyA', 'POS_TAG': 'VERB'}
# {'ID': '6', 'WORD': 'WA', 'POS_TAG': 'AUX'}
# {'ID': '7', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'isakA', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'praveSa', 'POS_TAG': 'NOUN'}
# {'ID': '3', 'WORD': 'xvAra', 'POS_TAG': 'NOUN'}
# {'ID': '4', 'WORD': 'xo', 'POS_TAG': 'NUM'}
# {'ID': '5', 'WORD': 'maMjilA', 'POS_TAG': 'ADJ'}
# {'ID': '6', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '7', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'jisameM', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'cAra', 'POS_TAG': 'NUM'}
# {'ID': '3', 'WORD': 'meharAbeM', 'POS_TAG': 'NOUN'}
# {'ID': '4', 'WORD': 'hEM', 'POS_TAG': 'AUX'}
# {'ID': '5', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '6', 'WORD': 'muKya', 'POS_TAG': 'ADJ'}
# {'ID': '7', 'WORD': 'prArWanA', 'POS_TAG': 'NOUN'}
# {'ID': '8', 'WORD': 'hOYla', 'POS_TAG': 'NOUN'}
# {'ID': '9', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '10', 'WORD': 'jAne', 'POS_TAG': 'VERB'}
# {'ID': '11', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '12', 'WORD': 'lie', 'POS_TAG': 'ADP'}
# {'ID': '13', 'WORD': '9', 'POS_TAG': 'NUM'}
# {'ID': '14', 'WORD': 'praveSa', 'POS_TAG': 'NOUN'}
# {'ID': '15', 'WORD': 'xvAra', 'POS_TAG': 'NOUN'}
# {'ID': '16', 'WORD': 'hEM', 'POS_TAG': 'VERB'}
# {'ID': '17', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'pUrI', 'POS_TAG': 'ADJ'}
# {'ID': '2', 'WORD': 'imArawa', 'POS_TAG': 'NOUN'}
# {'ID': '3', 'WORD': 'behaxa', 'POS_TAG': 'ADV'}
# {'ID': '4', 'WORD': 'KUbasUrawa', 'POS_TAG': 'ADJ'}
# {'ID': '5', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '6', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'yahAz', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'lagane', 'POS_TAG': 'VERB'}
# {'ID': '3', 'WORD': 'vAlA', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'wIna', 'POS_TAG': 'NUM'}
# {'ID': '5', 'WORD': 'xina', 'POS_TAG': 'NOUN'}
# {'ID': '6', 'WORD': 'kA', 'POS_TAG': 'ADP'}
# {'ID': '7', 'WORD': 'ijwimA', 'POS_TAG': 'NOUN'}
# {'ID': '8', 'WORD': 'pUre', 'POS_TAG': 'ADJ'}
# {'ID': '9', 'WORD': 'xeSa', 'POS_TAG': 'NOUN'}
# {'ID': '10', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '11', 'WORD': 'logoM', 'POS_TAG': 'NOUN'}
# {'ID': '12', 'WORD': 'ko', 'POS_TAG': 'ADP'}
# {'ID': '13', 'WORD': 'AmaMwriwa', 'POS_TAG': 'ADJ'}
# {'ID': '14', 'WORD': 'karawA', 'POS_TAG': 'VERB'}
# {'ID': '15', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '16', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'SOkawa', 'POS_TAG': 'PROPN'}
# {'ID': '2', 'WORD': 'mahala', 'POS_TAG': 'PROPN'}
# {'ID': '3', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'sAmane', 'POS_TAG': 'ADP'}
# {'ID': '5', 'WORD': 'badZI', 'POS_TAG': 'ADJ'}
# {'ID': '6', 'WORD': 'JIla', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '8', 'WORD': 'kinAre', 'POS_TAG': 'NOUN'}
# {'ID': '9', 'WORD': 'sWiwa', 'POS_TAG': 'ADJ'}
# {'ID': '10', 'WORD': 'vAswukalA', 'POS_TAG': 'NOUN'}
# {'ID': '11', 'WORD': 'kA', 'POS_TAG': 'ADP'}
# {'ID': '12', 'WORD': 'yaha', 'POS_TAG': 'DET'}
# {'ID': '13', 'WORD': 'KUbasUrawa', 'POS_TAG': 'ADJ'}
# {'ID': '14', 'WORD': 'namUnA', 'POS_TAG': 'NOUN'}
# {'ID': '15', 'WORD': 'kuxasiyA', 'POS_TAG': 'PROPN'}
# {'ID': '16', 'WORD': 'begama', 'POS_TAG': 'PROPN'}
# {'ID': '17', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '18', 'WORD': 'kAla', 'POS_TAG': 'NOUN'}
# {'ID': '19', 'WORD': 'kA', 'POS_TAG': 'ADP'}
# {'ID': '20', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '21', 'WORD': 'jinheM', 'POS_TAG': 'PRON'}
# {'ID': '22', 'WORD': 'gohara', 'POS_TAG': 'PROPN'}
# {'ID': '23', 'WORD': 'begama', 'POS_TAG': 'PROPN'}
# {'ID': '24', 'WORD': 'BI', 'POS_TAG': 'PART'}
# {'ID': '25', 'WORD': 'kahA', 'POS_TAG': 'VERB'}
# {'ID': '26', 'WORD': 'jAwA', 'POS_TAG': 'AUX'}
# {'ID': '27', 'WORD': 'WA', 'POS_TAG': 'AUX'}
# {'ID': '28', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'yaha', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'hiMxU', 'POS_TAG': 'NOUN'}
# {'ID': '3', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '4', 'WORD': 'mugala', 'POS_TAG': 'NOUN'}
# {'ID': '5', 'WORD': 'kalA', 'POS_TAG': 'NOUN'}
# {'ID': '6', 'WORD': 'kA', 'POS_TAG': 'ADP'}
# {'ID': '7', 'WORD': 'axBuwa', 'POS_TAG': 'ADJ'}
# {'ID': '8', 'WORD': 'saMgama', 'POS_TAG': 'NOUN'}
# {'ID': '9', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '10', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'yaha', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'BArawa', 'POS_TAG': 'PROPN'}
# {'ID': '3', 'WORD': 'kI', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'anUTI', 'POS_TAG': 'ADJ'}
# {'ID': '5', 'WORD': 'rARtrIya', 'POS_TAG': 'ADJ'}
# {'ID': '6', 'WORD': 'saMsWA', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '8', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'muKya', 'POS_TAG': 'ADJ'}
# {'ID': '2', 'WORD': 'rUpa', 'POS_TAG': 'NOUN'}
# {'ID': '3', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'yaha', 'POS_TAG': 'PRON'}
# {'ID': '5', 'WORD': 'praxarSana', 'POS_TAG': 'NOUN'}
# {'ID': '6', 'WORD': 'kalA', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '8', 'WORD': 'xqSya', 'POS_TAG': 'NOUN'}
# {'ID': '9', 'WORD': 'kalA', 'POS_TAG': 'NOUN'}
# {'ID': '10', 'WORD': 'kA', 'POS_TAG': 'ADP'}
# {'ID': '11', 'WORD': 'keMxra', 'POS_TAG': 'NOUN'}
# {'ID': '12', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '13', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'ise', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'cArlsa', 'POS_TAG': 'NOUN'}
# {'ID': '3', 'WORD': 'koriyA', 'POS_TAG': 'PROPN'}
# {'ID': '4', 'WORD': 'ne', 'POS_TAG': 'ADP'}
# {'ID': '5', 'WORD': 'dijAina', 'POS_TAG': 'NOUN'}
# {'ID': '6', 'WORD': 'kiyA', 'POS_TAG': 'VERB'}
# {'ID': '7', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '8', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'viSAla', 'POS_TAG': 'ADJ'}
# {'ID': '2', 'WORD': 'kRewra', 'POS_TAG': 'NOUN'}
# {'ID': '3', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'PEle', 'POS_TAG': 'VERB'}
# {'ID': '5', 'WORD': 'isa', 'POS_TAG': 'DET'}
# {'ID': '6', 'WORD': 'Bavana', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '8', 'WORD': 'Asa', 'POS_TAG': 'NOUN'}
# {'ID': '9', 'WORD': '-', 'POS_TAG': 'PUNCT'}
# {'ID': '10', 'WORD': 'pAsa', 'POS_TAG': 'ADP'}
# {'ID': '11', 'WORD': 'kA', 'POS_TAG': 'ADP'}
# {'ID': '12', 'WORD': 'prAkqwika', 'POS_TAG': 'ADJ'}
# {'ID': '13', 'WORD': 'sOMxarya', 'POS_TAG': 'NOUN'}
# {'ID': '14', 'WORD': 'ise', 'POS_TAG': 'PRON'}
# {'ID': '15', 'WORD': 'Ora', 'POS_TAG': 'DET'}
# {'ID': '16', 'WORD': 'BI', 'POS_TAG': 'PART'}
# {'ID': '17', 'WORD': 'Bavya', 'POS_TAG': 'ADJ'}
# {'ID': '18', 'WORD': 'banAwA', 'POS_TAG': 'VERB'}
# {'ID': '19', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '20', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'yahIM', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'para', 'POS_TAG': 'ADP'}
# {'ID': '3', 'WORD': 'eka', 'POS_TAG': 'NUM'}
# {'ID': '4', 'WORD': 'kalA', 'POS_TAG': 'NOUN'}
# {'ID': '5', 'WORD': 'saMgrahAlaya', 'POS_TAG': 'NOUN'}
# {'ID': '6', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '7', 'WORD': 'kalA', 'POS_TAG': 'NOUN'}
# {'ID': '8', 'WORD': 'xIrGA', 'POS_TAG': 'NOUN'}
# {'ID': '9', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '10', 'WORD': 'PAina', 'POS_TAG': 'NOUN'}
# {'ID': '11', 'WORD': 'Arta', 'POS_TAG': 'NOUN'}
# {'ID': '12', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '13', 'WORD': 'lie', 'POS_TAG': 'ADP'}
# {'ID': '14', 'WORD': 'kAryaSAlA', 'POS_TAG': 'NOUN'}
# {'ID': '15', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '16', 'WORD': 'eka', 'POS_TAG': 'NUM'}
# {'ID': '17', 'WORD': 'Wietara', 'POS_TAG': 'NOUN'}
# {'ID': '18', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '19', 'WORD': 'aMwaraMga', 'POS_TAG': 'ADJ'}
# {'ID': '20', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '21', 'WORD': 'bahiraMga', 'POS_TAG': 'ADJ'}
# {'ID': '22', 'WORD': 'OYditoriyama', 'POS_TAG': 'NOUN'}
# {'ID': '23', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '24', 'WORD': 'riharsala', 'POS_TAG': 'NOUN'}
# {'ID': '25', 'WORD': 'kakRa', 'POS_TAG': 'NOUN'}
# {'ID': '26', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '27', 'WORD': 'BArawIya', 'POS_TAG': 'ADJ'}
# {'ID': '28', 'WORD': 'kaviwAoM', 'POS_TAG': 'NOUN'}
# {'ID': '29', 'WORD': 'kA', 'POS_TAG': 'ADP'}
# {'ID': '30', 'WORD': 'puswakAlaya', 'POS_TAG': 'NOUN'}
# {'ID': '31', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '32', 'WORD': 'SAswrIya', 'POS_TAG': 'ADJ'}
# {'ID': '33', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '34', 'WORD': 'loka', 'POS_TAG': 'ADJ'}
# {'ID': '35', 'WORD': 'saMgIwa', 'POS_TAG': 'NOUN'}
# {'ID': '36', 'WORD': 'saMgrahAlaya', 'POS_TAG': 'NOUN'}
# {'ID': '37', 'WORD': 'BI', 'POS_TAG': 'PART'}
# {'ID': '38', 'WORD': 'hEM', 'POS_TAG': 'AUX'}
# {'ID': '39', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'yaha', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'somavAra', 'POS_TAG': 'PROPN'}
# {'ID': '3', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'alAvA', 'POS_TAG': 'ADP'}
# {'ID': '5', 'WORD': 'pUre', 'POS_TAG': 'ADJ'}
# {'ID': '6', 'WORD': 'sapwAha', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': 'xopahara', 'POS_TAG': 'NOUN'}
# {'ID': '8', 'WORD': '2', 'POS_TAG': 'NUM'}
# {'ID': '9', 'WORD': 'baje', 'POS_TAG': 'NOUN'}
# {'ID': '10', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '11', 'WORD': 'rAwa', 'POS_TAG': 'NOUN'}
# {'ID': '12', 'WORD': '8', 'POS_TAG': 'NUM'}
# {'ID': '13', 'WORD': 'baje', 'POS_TAG': 'NOUN'}
# {'ID': '14', 'WORD': 'waka', 'POS_TAG': 'ADP'}
# {'ID': '15', 'WORD': 'KulA', 'POS_TAG': 'VERB'}
# {'ID': '16', 'WORD': 'rahawA', 'POS_TAG': 'AUX'}
# {'ID': '17', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '18', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'yaha', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'eka', 'POS_TAG': 'NUM'}
# {'ID': '3', 'WORD': 'anUTA', 'POS_TAG': 'ADJ'}
# {'ID': '4', 'WORD': 'saMgrahAlaya', 'POS_TAG': 'NOUN'}
# {'ID': '5', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '6', 'WORD': 'jo', 'POS_TAG': 'PRON'}
# {'ID': '7', 'WORD': '200', 'POS_TAG': 'NUM'}
# {'ID': '8', 'WORD': 'ekadZa', 'POS_TAG': 'NOUN'}
# {'ID': '9', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '10', 'WORD': 'SyAmalA', 'POS_TAG': 'PROPN'}
# {'ID': '11', 'WORD': 'hilsa', 'POS_TAG': 'PROPN'}
# {'ID': '12', 'WORD': 'para', 'POS_TAG': 'ADP'}
# {'ID': '13', 'WORD': 'badZI', 'POS_TAG': 'ADJ'}
# {'ID': '14', 'WORD': 'JIla', 'POS_TAG': 'NOUN'}
# {'ID': '15', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '16', 'WORD': 'sAmane', 'POS_TAG': 'ADP'}
# {'ID': '17', 'WORD': 'PElA', 'POS_TAG': 'VERB'}
# {'ID': '18', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '19', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'yaha', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'eka', 'POS_TAG': 'NUM'}
# {'ID': '3', 'WORD': 'prAgEwihAsika', 'POS_TAG': 'ADJ'}
# {'ID': '4', 'WORD': 'sWala', 'POS_TAG': 'NOUN'}
# {'ID': '5', 'WORD': 'para', 'POS_TAG': 'ADP'}
# {'ID': '6', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '7', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '8', 'WORD': 'viSva', 'POS_TAG': 'NOUN'}
# {'ID': '9', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '10', 'WORD': 'apanI', 'POS_TAG': 'PRON'}
# {'ID': '11', 'WORD': 'waraha', 'POS_TAG': 'NOUN'}
# {'ID': '12', 'WORD': 'kA', 'POS_TAG': 'ADP'}
# {'ID': '13', 'WORD': 'eka', 'POS_TAG': 'NUM'}
# {'ID': '14', 'WORD': 'hI', 'POS_TAG': 'PART'}
# {'ID': '15', 'WORD': 'saMgrahAlaya', 'POS_TAG': 'NOUN'}
# {'ID': '16', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '17', 'WORD': 'jo', 'POS_TAG': 'PRON'}
# {'ID': '18', 'WORD': 'prAgEwihAsika', 'POS_TAG': 'ADJ'}
# {'ID': '19', 'WORD': 'ciwrakalA', 'POS_TAG': 'NOUN'}
# {'ID': '20', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '21', 'WORD': 'sajjiwa', 'POS_TAG': 'ADJ'}
# {'ID': '22', 'WORD': 'guPAoM', 'POS_TAG': 'NOUN'}
# {'ID': '23', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '24', 'WORD': 'samIpa', 'POS_TAG': 'ADP'}
# {'ID': '25', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '26', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '2', 'WORD': 'isa', 'POS_TAG': 'DET'}
# {'ID': '3', 'WORD': 'waraha', 'POS_TAG': 'NOUN'}
# {'ID': '4', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '5', 'WORD': 'yaha', 'POS_TAG': 'PRON'}
# {'ID': '6', 'WORD': 'vaswuoM', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '8', 'WORD': 'paraMparAoM', 'POS_TAG': 'NOUN'}
# {'ID': '9', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '10', 'WORD': 'jIvaMwa', 'POS_TAG': 'ADJ'}
# {'ID': '11', 'WORD': 'rUpa', 'POS_TAG': 'NOUN'}
# {'ID': '12', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '13', 'WORD': 'judZA', 'POS_TAG': 'VERB'}
# {'ID': '14', 'WORD': 'huA', 'POS_TAG': 'AUX'}
# {'ID': '15', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '16', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'yahAz', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'AxivAsI', 'POS_TAG': 'NOUN'}
# {'ID': '3', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '4', 'WORD': 'samuxra', 'POS_TAG': 'NOUN'}
# {'ID': '5', 'WORD': 'kinAre', 'POS_TAG': 'NOUN'}
# {'ID': '6', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '7', 'WORD': 'regiswAna', 'POS_TAG': 'NOUN'}
# {'ID': '8', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '9', 'WORD': 'himAlaya', 'POS_TAG': 'PROPN'}
# {'ID': '10', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '11', 'WORD': 'AvAsoM', 'POS_TAG': 'NOUN'}
# {'ID': '12', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '13', 'WORD': 'namUne', 'POS_TAG': 'NOUN'}
# {'ID': '14', 'WORD': 'BI', 'POS_TAG': 'PART'}
# {'ID': '15', 'WORD': 'banAe', 'POS_TAG': 'VERB'}
# {'ID': '16', 'WORD': 'gae', 'POS_TAG': 'AUX'}
# {'ID': '17', 'WORD': 'hEM', 'POS_TAG': 'AUX'}
# {'ID': '18', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'yahAz', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'saMgrahAlaya', 'POS_TAG': 'NOUN'}
# {'ID': '3', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'puswakAlaya', 'POS_TAG': 'NOUN'}
# {'ID': '5', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '6', 'WORD': 'xqSya', 'POS_TAG': 'ADJ'}
# {'ID': '7', 'WORD': '-', 'POS_TAG': 'PUNCT'}
# {'ID': '8', 'WORD': 'Srqvya', 'POS_TAG': 'ADJ'}
# {'ID': '9', 'WORD': 'ArkAiva', 'POS_TAG': 'NOUN'}
# {'ID': '10', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '11', 'WORD': 'kaMpyUtarIkqwa', 'POS_TAG': 'ADJ'}
# {'ID': '12', 'WORD': 'kakRa', 'POS_TAG': 'NOUN'}
# {'ID': '13', 'WORD': 'va', 'POS_TAG': 'CCONJ'}
# {'ID': '14', 'WORD': 'prajAwIya', 'POS_TAG': 'ADJ'}
# {'ID': '15', 'WORD': 'namUnoM', 'POS_TAG': 'NOUN'}
# {'ID': '16', 'WORD': 'ko', 'POS_TAG': 'ADP'}
# {'ID': '17', 'WORD': 'xeKA', 'POS_TAG': 'VERB'}
# {'ID': '18', 'WORD': 'jAwA', 'POS_TAG': 'AUX'}
# {'ID': '19', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '20', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'yahAz', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'maXya', 'POS_TAG': 'PROPN'}
# {'ID': '3', 'WORD': 'praxeSa', 'POS_TAG': 'PROPN'}
# {'ID': '4', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '5', 'WORD': 'viBinna', 'POS_TAG': 'ADJ'}
# {'ID': '6', 'WORD': 'hissoM', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '8', 'WORD': 'kalA', 'POS_TAG': 'NOUN'}
# {'ID': '9', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '10', 'WORD': 'KUbasUrawa', 'POS_TAG': 'ADJ'}
# {'ID': '11', 'WORD': 'namUne', 'POS_TAG': 'NOUN'}
# {'ID': '12', 'WORD': 'ekawriwa', 'POS_TAG': 'ADJ'}
# {'ID': '13', 'WORD': 'karake', 'POS_TAG': 'VERB'}
# {'ID': '14', 'WORD': 'raKe', 'POS_TAG': 'VERB'}
# {'ID': '15', 'WORD': 'gae', 'POS_TAG': 'AUX'}
# {'ID': '16', 'WORD': 'hEM', 'POS_TAG': 'AUX'}
# {'ID': '17', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'saMgrahAlaya', 'POS_TAG': 'NOUN'}
# {'ID': '2', 'WORD': 'somavAra', 'POS_TAG': 'PROPN'}
# {'ID': '3', 'WORD': 'ko', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'baMxa', 'POS_TAG': 'ADJ'}
# {'ID': '5', 'WORD': 'rahawA', 'POS_TAG': 'VERB'}
# {'ID': '6', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '7', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'yaha', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'arerA', 'POS_TAG': 'PROPN'}
# {'ID': '3', 'WORD': 'hilsa', 'POS_TAG': 'PROPN'}
# {'ID': '4', 'WORD': 'para', 'POS_TAG': 'ADP'}
# {'ID': '5', 'WORD': 'sWiwa', 'POS_TAG': 'ADJ'}
# {'ID': '6', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '7', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'isase', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'lagA', 'POS_TAG': 'VERB'}
# {'ID': '3', 'WORD': 'huA', 'POS_TAG': 'AUX'}
# {'ID': '4', 'WORD': 'eka', 'POS_TAG': 'NUM'}
# {'ID': '5', 'WORD': 'saMgrahAlaya', 'POS_TAG': 'NOUN'}
# {'ID': '6', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '7', 'WORD': 'jahAz', 'POS_TAG': 'PRON'}
# {'ID': '8', 'WORD': 'maXyapraxeSa', 'POS_TAG': 'PROPN'}
# {'ID': '9', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '10', 'WORD': 'rAyasena', 'POS_TAG': 'PROPN'}
# {'ID': '11', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '12', 'WORD': 'sIhora', 'POS_TAG': 'PROPN'}
# {'ID': '13', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '14', 'WORD': 'maMxasOra', 'POS_TAG': 'PROPN'}
# {'ID': '15', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '16', 'WORD': 'Sahadola', 'POS_TAG': 'PROPN'}
# {'ID': '17', 'WORD': 'jiloM', 'POS_TAG': 'NOUN'}
# {'ID': '18', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '19', 'WORD': 'ekawriwa', 'POS_TAG': 'ADJ'}
# {'ID': '20', 'WORD': 'kalA', 'POS_TAG': 'NOUN'}
# {'ID': '21', 'WORD': 'namUnoM', 'POS_TAG': 'NOUN'}
# {'ID': '22', 'WORD': 'ko', 'POS_TAG': 'ADP'}
# {'ID': '23', 'WORD': 'raKA', 'POS_TAG': 'VERB'}
# {'ID': '24', 'WORD': 'gayA', 'POS_TAG': 'AUX'}
# {'ID': '25', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '26', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'yaha', 'POS_TAG': 'DET'}
# {'ID': '2', 'WORD': 'saMgrahAlaya', 'POS_TAG': 'NOUN'}
# {'ID': '3', 'WORD': 'BI', 'POS_TAG': 'PART'}
# {'ID': '4', 'WORD': 'somavAra', 'POS_TAG': 'PROPN'}
# {'ID': '5', 'WORD': 'ko', 'POS_TAG': 'ADP'}
# {'ID': '6', 'WORD': 'CodZakara', 'POS_TAG': 'VERB'}
# {'ID': '7', 'WORD': 'pUre', 'POS_TAG': 'ADJ'}
# {'ID': '8', 'WORD': 'sapwAha', 'POS_TAG': 'NOUN'}
# {'ID': '9', 'WORD': '9', 'POS_TAG': 'NUM'}
# {'ID': '10', 'WORD': 'baje', 'POS_TAG': 'NOUN'}
# {'ID': '11', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '12', 'WORD': '5', 'POS_TAG': 'NUM'}
# {'ID': '13', 'WORD': 'baje', 'POS_TAG': 'NOUN'}
# {'ID': '14', 'WORD': 'waka', 'POS_TAG': 'ADP'}
# {'ID': '15', 'WORD': 'KulA', 'POS_TAG': 'VERB'}
# {'ID': '16', 'WORD': 'rahawA', 'POS_TAG': 'AUX'}
# {'ID': '17', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '18', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'badZI', 'POS_TAG': 'ADJ'}
# {'ID': '2', 'WORD': 'JIla', 'POS_TAG': 'NOUN'}
# {'ID': '3', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'lagI', 'POS_TAG': 'VERB'}
# {'ID': '5', 'WORD': 'pahAdZI', 'POS_TAG': 'NOUN'}
# {'ID': '6', 'WORD': 'para', 'POS_TAG': 'ADP'}
# {'ID': '7', 'WORD': 'yaha', 'POS_TAG': 'DET'}
# {'ID': '8', 'WORD': 'saPArI', 'POS_TAG': 'NOUN'}
# {'ID': '9', 'WORD': 'uxyAna', 'POS_TAG': 'NOUN'}
# {'ID': '10', 'WORD': 'sWiwa', 'POS_TAG': 'ADJ'}
# {'ID': '11', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '12', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'yaha', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': '445', 'POS_TAG': 'NUM'}
# {'ID': '3', 'WORD': 'hEkteyara', 'POS_TAG': 'NOUN'}
# {'ID': '4', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '5', 'WORD': 'PElA', 'POS_TAG': 'VERB'}
# {'ID': '6', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '7', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'prAkqwika', 'POS_TAG': 'ADJ'}
# {'ID': '2', 'WORD': 'suMxarawA', 'POS_TAG': 'NOUN'}
# {'ID': '3', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'bIca', 'POS_TAG': 'ADP'}
# {'ID': '5', 'WORD': 'Apa', 'POS_TAG': 'PRON'}
# {'ID': '6', 'WORD': 'viBinna', 'POS_TAG': 'ADJ'}
# {'ID': '7', 'WORD': 'prakAra', 'POS_TAG': 'NOUN'}
# {'ID': '8', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '9', 'WORD': 'SAkAhArI', 'POS_TAG': 'ADJ'}
# {'ID': '10', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '11', 'WORD': 'mAzsAhArI', 'POS_TAG': 'ADJ'}
# {'ID': '12', 'WORD': 'prANiyoM', 'POS_TAG': 'NOUN'}
# {'ID': '13', 'WORD': 'ko', 'POS_TAG': 'ADP'}
# {'ID': '14', 'WORD': 'xeKane', 'POS_TAG': 'VERB'}
# {'ID': '15', 'WORD': 'kA', 'POS_TAG': 'ADP'}
# {'ID': '16', 'WORD': 'AnaMxa', 'POS_TAG': 'NOUN'}
# {'ID': '17', 'WORD': 'uTA', 'POS_TAG': 'VERB'}
# {'ID': '18', 'WORD': 'sakawe', 'POS_TAG': 'AUX'}
# {'ID': '19', 'WORD': 'hEM', 'POS_TAG': 'AUX'}
# {'ID': '20', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'yaha', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'maMgalavAra', 'POS_TAG': 'PROPN'}
# {'ID': '3', 'WORD': 'ko', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'CodZakara', 'POS_TAG': 'VERB'}
# {'ID': '5', 'WORD': 'hara', 'POS_TAG': 'DET'}
# {'ID': '6', 'WORD': 'xina', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': 'subaha', 'POS_TAG': 'NOUN'}
# {'ID': '8', 'WORD': '7', 'POS_TAG': 'NUM'}
# {'ID': '9', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '10', 'WORD': '11', 'POS_TAG': 'NUM'}
# {'ID': '11', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '12', 'WORD': '3', 'POS_TAG': 'NUM'}
# {'ID': '13', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '14', 'WORD': '5', 'POS_TAG': 'NUM'}
# {'ID': '15', 'WORD': 'baje', 'POS_TAG': 'NOUN'}
# {'ID': '16', 'WORD': 'SAma', 'POS_TAG': 'NOUN'}
# {'ID': '17', 'WORD': 'waka', 'POS_TAG': 'ADP'}
# {'ID': '18', 'WORD': 'KulA', 'POS_TAG': 'VERB'}
# {'ID': '19', 'WORD': 'rahawA', 'POS_TAG': 'AUX'}
# {'ID': '20', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '21', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'yaha', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'mUla', 'POS_TAG': 'ADJ'}
# {'ID': '3', 'WORD': 'rUpa', 'POS_TAG': 'NOUN'}
# {'ID': '4', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '5', 'WORD': 'vijFAna', 'POS_TAG': 'NOUN'}
# {'ID': '6', 'WORD': 'saMgrahAlaya', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '8', 'WORD': 'jo', 'POS_TAG': 'PRON'}
# {'ID': '9', 'WORD': 'SyAmalA', 'POS_TAG': 'PROPN'}
# {'ID': '10', 'WORD': 'hilsa', 'POS_TAG': 'PROPN'}
# {'ID': '11', 'WORD': 'kI', 'POS_TAG': 'ADP'}
# {'ID': '12', 'WORD': 'KUbasUrawI', 'POS_TAG': 'NOUN'}
# {'ID': '13', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '14', 'WORD': 'bIca', 'POS_TAG': 'ADP'}
# {'ID': '15', 'WORD': 'sWiwa', 'POS_TAG': 'ADJ'}
# {'ID': '16', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '17', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'yahAz', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'inveMSana', 'POS_TAG': 'NOUN'}
# {'ID': '3', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '4', 'WORD': 'Pana', 'POS_TAG': 'NOUN'}
# {'ID': '5', 'WORD': 'sAiMsa', 'POS_TAG': 'NOUN'}
# {'ID': '6', 'WORD': 'gElarI', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': 'hEM', 'POS_TAG': 'AUX'}
# {'ID': '8', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '9', 'WORD': 'eka', 'POS_TAG': 'NUM'}
# {'ID': '10', 'WORD': 'wArAmaMdala', 'POS_TAG': 'PROPN'}
# {'ID': '11', 'WORD': 'nAma', 'POS_TAG': 'NOUN'}
# {'ID': '12', 'WORD': 'kA', 'POS_TAG': 'ADP'}
# {'ID': '13', 'WORD': 'pleneteriyama', 'POS_TAG': 'NOUN'}
# {'ID': '14', 'WORD': 'BI', 'POS_TAG': 'PART'}
# {'ID': '15', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '16', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'yaha', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'somavAra', 'POS_TAG': 'PROPN'}
# {'ID': '3', 'WORD': 'ko', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'CodZakara', 'POS_TAG': 'VERB'}
# {'ID': '5', 'WORD': 'hara', 'POS_TAG': 'DET'}
# {'ID': '6', 'WORD': 'xina', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': 'subaha', 'POS_TAG': 'NOUN'}
# {'ID': '8', 'WORD': '10.3', 'POS_TAG': 'NUM'}
# {'ID': '9', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '10', 'WORD': '6.3', 'POS_TAG': 'NUM'}
# {'ID': '11', 'WORD': 'waka', 'POS_TAG': 'ADP'}
# {'ID': '12', 'WORD': 'KulA', 'POS_TAG': 'VERB'}
# {'ID': '13', 'WORD': 'rahawA', 'POS_TAG': 'AUX'}
# {'ID': '14', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '15', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'Sahara', 'POS_TAG': 'NOUN'}
# {'ID': '2', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '3', 'WORD': 'bIca', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'sWiwa', 'POS_TAG': 'ADJ'}
# {'ID': '5', 'WORD': 'cOka', 'POS_TAG': 'PROPN'}
# {'ID': '6', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '7', 'WORD': 'purAnI', 'POS_TAG': 'ADJ'}
# {'ID': '8', 'WORD': 'masjixa', 'POS_TAG': 'NOUN'}
# {'ID': '9', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '10', 'WORD': 'haveliyAz', 'POS_TAG': 'NOUN'}
# {'ID': '11', 'WORD': 'awIwa', 'POS_TAG': 'NOUN'}
# {'ID': '12', 'WORD': 'kI', 'POS_TAG': 'ADP'}
# {'ID': '13', 'WORD': 'smqwi', 'POS_TAG': 'NOUN'}
# {'ID': '14', 'WORD': 'xilAwe', 'POS_TAG': 'VERB'}
# {'ID': '15', 'WORD': 'hEM', 'POS_TAG': 'AUX'}
# {'ID': '16', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'sazkarI', 'POS_TAG': 'ADJ'}
# {'ID': '2', 'WORD': 'galiyoM', 'POS_TAG': 'NOUN'}
# {'ID': '3', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'sWiwa', 'POS_TAG': 'ADJ'}
# {'ID': '5', 'WORD': 'xukAneM', 'POS_TAG': 'NOUN'}
# {'ID': '6', 'WORD': 'hEM', 'POS_TAG': 'AUX'}
# {'ID': '7', 'WORD': 'jinameM', 'POS_TAG': 'PRON'}
# {'ID': '8', 'WORD': 'Silpa', 'POS_TAG': 'NOUN'}
# {'ID': '9', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '10', 'WORD': 'KajAne', 'POS_TAG': 'NOUN'}
# {'ID': '11', 'WORD': 'Kule', 'POS_TAG': 'VERB'}
# {'ID': '12', 'WORD': 'hue', 'POS_TAG': 'AUX'}
# {'ID': '13', 'WORD': 'hEM', 'POS_TAG': 'AUX'}
# {'ID': '14', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'yahAz', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'Apa', 'POS_TAG': 'PRON'}
# {'ID': '3', 'WORD': 'cAzxI', 'POS_TAG': 'NOUN'}
# {'ID': '4', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '5', 'WORD': 'ABURaNa', 'POS_TAG': 'NOUN'}
# {'ID': '6', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '7', 'WORD': 'bIdavarka', 'POS_TAG': 'NOUN'}
# {'ID': '8', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '9', 'WORD': 'kaDZAI', 'POS_TAG': 'NOUN'}
# {'ID': '10', 'WORD': 'kA', 'POS_TAG': 'ADP'}
# {'ID': '11', 'WORD': 'kAma', 'POS_TAG': 'NOUN'}
# {'ID': '12', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '13', 'WORD': 'sIkvana', 'POS_TAG': 'NOUN'}
# {'ID': '14', 'WORD': 'kA', 'POS_TAG': 'ADP'}
# {'ID': '15', 'WORD': 'kAma', 'POS_TAG': 'NOUN'}
# {'ID': '16', 'WORD': 'KUbasUrawa', 'POS_TAG': 'ADJ'}
# {'ID': '17', 'WORD': 'aMxAja', 'POS_TAG': 'NOUN'}
# {'ID': '18', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '19', 'WORD': 'xeKa', 'POS_TAG': 'VERB'}
# {'ID': '20', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '21', 'WORD': 'KarIxa', 'POS_TAG': 'VERB'}
# {'ID': '22', 'WORD': 'sakawe', 'POS_TAG': 'AUX'}
# {'ID': '23', 'WORD': 'hEM', 'POS_TAG': 'AUX'}
# {'ID': '24', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'badZI', 'POS_TAG': 'PROPN'}
# {'ID': '2', 'WORD': 'JIla', 'POS_TAG': 'PROPN'}
# {'ID': '3', 'WORD': 'CotI', 'POS_TAG': 'PROPN'}
# {'ID': '4', 'WORD': 'JIla', 'POS_TAG': 'PROPN'}
# {'ID': '5', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '6', 'WORD': 'eka', 'POS_TAG': 'NUM'}
# {'ID': '7', 'WORD': 'ovarabrija', 'POS_TAG': 'NOUN'}
# {'ID': '8', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '9', 'WORD': 'alaga', 'POS_TAG': 'ADJ'}
# {'ID': '10', 'WORD': 'howI', 'POS_TAG': 'VERB'}
# {'ID': '11', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '12', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'ma.pra.', 'POS_TAG': 'PROPN'}
# {'ID': '2', 'WORD': 'paryatana', 'POS_TAG': 'PROPN'}
# {'ID': '3', 'WORD': 'bota', 'POS_TAG': 'PROPN'}
# {'ID': '4', 'WORD': 'klaba', 'POS_TAG': 'PROPN'}
# {'ID': '5', 'WORD': 'badZI', 'POS_TAG': 'PROPN'}
# {'ID': '6', 'WORD': 'JIla', 'POS_TAG': 'PROPN'}
# {'ID': '7', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '8', 'WORD': 'nOkAyana', 'POS_TAG': 'NOUN'}
# {'ID': '9', 'WORD': 'BI', 'POS_TAG': 'PART'}
# {'ID': '10', 'WORD': 'karavAwA', 'POS_TAG': 'VERB'}
# {'ID': '11', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '12', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'CotI', 'POS_TAG': 'PROPN'}
# {'ID': '2', 'WORD': 'JIla', 'POS_TAG': 'PROPN'}
# {'ID': '3', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'eka', 'POS_TAG': 'NUM'}
# {'ID': '5', 'WORD': 'maCalI', 'POS_TAG': 'NOUN'}
# {'ID': '6', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '7', 'WORD': 'AkAra', 'POS_TAG': 'NOUN'}
# {'ID': '8', 'WORD': 'kA', 'POS_TAG': 'ADP'}
# {'ID': '9', 'WORD': 'ekveriyama', 'POS_TAG': 'NOUN'}
# {'ID': '10', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '11', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'kEse', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'pahuzce', 'POS_TAG': 'VERB'}
# {'ID': '3', 'WORD': '?', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'xillI', 'POS_TAG': 'PROPN'}
# {'ID': '2', 'WORD': 'gvAliyara', 'POS_TAG': 'PROPN'}
# {'ID': '3', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '4', 'WORD': 'iMxOra', 'POS_TAG': 'PROPN'}
# {'ID': '5', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '6', 'WORD': 'muMbaI', 'POS_TAG': 'PROPN'}
# {'ID': '7', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '8', 'WORD': 'BopAla', 'POS_TAG': 'PROPN'}
# {'ID': '9', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '10', 'WORD': 'lie', 'POS_TAG': 'ADP'}
# {'ID': '11', 'WORD': 'niyamiwa', 'POS_TAG': 'ADJ'}
# {'ID': '12', 'WORD': 'vimAna', 'POS_TAG': 'NOUN'}
# {'ID': '13', 'WORD': 'sevA', 'POS_TAG': 'NOUN'}
# {'ID': '14', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '15', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'BopAla', 'POS_TAG': 'PROPN'}
# {'ID': '2', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '3', 'WORD': 'xillI', 'POS_TAG': 'PROPN'}
# {'ID': '4', 'WORD': '-', 'POS_TAG': 'PUNCT'}
# {'ID': '5', 'WORD': 'maxrAsa', 'POS_TAG': 'PROPN'}
# {'ID': '6', 'WORD': 'mena', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': 'lAina', 'POS_TAG': 'NOUN'}
# {'ID': '8', 'WORD': 'para', 'POS_TAG': 'ADP'}
# {'ID': '9', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '10', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'muMbaI', 'POS_TAG': 'PROPN'}
# {'ID': '2', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '3', 'WORD': 'itArasI', 'POS_TAG': 'PROPN'}
# {'ID': '4', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '5', 'WORD': 'JAzsI', 'POS_TAG': 'PROPN'}
# {'ID': '6', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '7', 'WORD': 'rAswe', 'POS_TAG': 'NOUN'}
# {'ID': '8', 'WORD': 'xillI', 'POS_TAG': 'PROPN'}
# {'ID': '9', 'WORD': 'jAne', 'POS_TAG': 'VERB'}
# {'ID': '10', 'WORD': 'vAlI', 'POS_TAG': 'ADP'}
# {'ID': '11', 'WORD': 'muKya', 'POS_TAG': 'ADJ'}
# {'ID': '12', 'WORD': 'gAdZiyAz', 'POS_TAG': 'NOUN'}
# {'ID': '13', 'WORD': 'BopAla', 'POS_TAG': 'PROPN'}
# {'ID': '14', 'WORD': 'hokara', 'POS_TAG': 'VERB'}
# {'ID': '15', 'WORD': 'jAwI', 'POS_TAG': 'VERB'}
# {'ID': '16', 'WORD': 'hEM', 'POS_TAG': 'AUX'}
# {'ID': '17', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'BopAla', 'POS_TAG': 'PROPN'}
# {'ID': '2', 'WORD': 'waWA', 'POS_TAG': 'CCONJ'}
# {'ID': '3', 'WORD': 'iMxOra', 'POS_TAG': 'PROPN'}
# {'ID': '4', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '5', 'WORD': 'mAMdU', 'POS_TAG': 'PROPN'}
# {'ID': '6', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '7', 'WORD': 'ujjEna', 'POS_TAG': 'PROPN'}
# {'ID': '8', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '9', 'WORD': 'KajurAho', 'POS_TAG': 'PROPN'}
# {'ID': '10', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '11', 'WORD': 'pacamaDZI', 'POS_TAG': 'PROPN'}
# {'ID': '12', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '13', 'WORD': 'gvAliyara', 'POS_TAG': 'PROPN'}
# {'ID': '14', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '15', 'WORD': 'sAzcI', 'POS_TAG': 'PROPN'}
# {'ID': '16', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '17', 'WORD': 'jabalapura', 'POS_TAG': 'PROPN'}
# {'ID': '18', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '19', 'WORD': 'SivapurI', 'POS_TAG': 'PROPN'}
# {'ID': '20', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '21', 'WORD': 'bIca', 'POS_TAG': 'ADP'}
# {'ID': '22', 'WORD': 'niyamiwa', 'POS_TAG': 'ADJ'}
# {'ID': '23', 'WORD': 'basa', 'POS_TAG': 'NOUN'}
# {'ID': '24', 'WORD': 'sevAez', 'POS_TAG': 'NOUN'}
# {'ID': '25', 'WORD': 'hEM', 'POS_TAG': 'AUX'}
# {'ID': '26', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'Taharane', 'POS_TAG': 'VERB'}
# {'ID': '2', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '3', 'WORD': 'lie', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': '-', 'POS_TAG': 'PUNCT'}
# {'ID': '5', 'WORD': 'maXyapraxeSa', 'POS_TAG': 'PROPN'}
# {'ID': '6', 'WORD': 'paryatana', 'POS_TAG': 'PROPN'}
# {'ID': '7', 'WORD': 'vikAsa', 'POS_TAG': 'PROPN'}
# {'ID': '8', 'WORD': 'nigama', 'POS_TAG': 'PROPN'}
# {'ID': '9', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '10', 'WORD': 'hotala', 'POS_TAG': 'NOUN'}
# {'ID': '11', 'WORD': 'waWA', 'POS_TAG': 'CCONJ'}
# {'ID': '12', 'WORD': 'nijI', 'POS_TAG': 'ADJ'}
# {'ID': '13', 'WORD': 'hotala', 'POS_TAG': 'NOUN'}
# {'ID': '14', 'WORD': 'hEM', 'POS_TAG': 'VERB'}
# {'ID': '15', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'kaba', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'jAez', 'POS_TAG': 'VERB'}
# {'ID': '3', 'WORD': '?', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'varRa', 'POS_TAG': 'NOUN'}
# {'ID': '2', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '3', 'WORD': 'kaBI', 'POS_TAG': 'PRON'}
# {'ID': '4', 'WORD': 'BI', 'POS_TAG': 'PART'}
# {'ID': '5', 'WORD': 'Apa', 'POS_TAG': 'PRON'}
# {'ID': '6', 'WORD': 'yahAz', 'POS_TAG': 'PRON'}
# {'ID': '7', 'WORD': 'jA', 'POS_TAG': 'VERB'}
# {'ID': '8', 'WORD': 'sakawe', 'POS_TAG': 'AUX'}
# {'ID': '9', 'WORD': 'hEM', 'POS_TAG': 'AUX'}
# {'ID': '10', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'oraCA', 'POS_TAG': 'PROPN'}
# {'ID': '2', 'WORD': 'kA', 'POS_TAG': 'ADP'}
# {'ID': '3', 'WORD': 'vEBava', 'POS_TAG': 'NOUN'}
# {'ID': '4', 'WORD': 'pawWaroM', 'POS_TAG': 'NOUN'}
# {'ID': '5', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '6', 'WORD': 'jEse', 'POS_TAG': 'PART'}
# {'ID': '7', 'WORD': 'kExa', 'POS_TAG': 'NOUN'}
# {'ID': '8', 'WORD': 'ho', 'POS_TAG': 'VERB'}
# {'ID': '9', 'WORD': 'gayA', 'POS_TAG': 'AUX'}
# {'ID': '10', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '11', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '12', 'WORD': 'samaya', 'POS_TAG': 'NOUN'}
# {'ID': '13', 'WORD': 'yahAz', 'POS_TAG': 'PRON'}
# {'ID': '14', 'WORD': 'TaharA', 'POS_TAG': 'VERB'}
# {'ID': '15', 'WORD': 'huA', 'POS_TAG': 'AUX'}
# {'ID': '16', 'WORD': 'lagawA', 'POS_TAG': 'VERB'}
# {'ID': '17', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '18', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '19', 'WORD': 'hama', 'POS_TAG': 'PRON'}
# {'ID': '20', 'WORD': 'cale', 'POS_TAG': 'VERB'}
# {'ID': '21', 'WORD': 'jAwe', 'POS_TAG': 'AUX'}
# {'ID': '22', 'WORD': 'hEM', 'POS_TAG': 'AUX'}
# {'ID': '23', 'WORD': 'barasoM', 'POS_TAG': 'NOUN'}
# {'ID': '24', 'WORD': 'barasa', 'POS_TAG': 'NOUN'}
# {'ID': '25', 'WORD': 'pICe', 'POS_TAG': 'ADP'}
# {'ID': '26', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '27', 'WORD': 'maXyakAla', 'POS_TAG': 'PROPN'}
# {'ID': '28', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '29', 'WORD': 'eka', 'POS_TAG': 'NUM'}
# {'ID': '30', 'WORD': 'Sahara', 'POS_TAG': 'NOUN'}
# {'ID': '31', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '32', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'jahAz', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '3', 'WORD': 'maMxiroM', 'POS_TAG': 'NOUN'}
# {'ID': '4', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '5', 'WORD': 'mahaloM', 'POS_TAG': 'NOUN'}
# {'ID': '6', 'WORD': 'kI', 'POS_TAG': 'ADP'}
# {'ID': '7', 'WORD': 'camaka', 'POS_TAG': 'NOUN'}
# {'ID': '8', 'WORD': 'ko', 'POS_TAG': 'ADP'}
# {'ID': '9', 'WORD': 'samaya', 'POS_TAG': 'NOUN'}
# {'ID': '10', 'WORD': 'kI', 'POS_TAG': 'ADP'}
# {'ID': '11', 'WORD': 'XuMXa', 'POS_TAG': 'NOUN'}
# {'ID': '12', 'WORD': 'BI', 'POS_TAG': 'PART'}
# {'ID': '13', 'WORD': 'XuzXalA', 'POS_TAG': 'VERB'}
# {'ID': '14', 'WORD': 'nahIM', 'POS_TAG': 'PART'}
# {'ID': '15', 'WORD': 'sakI', 'POS_TAG': 'AUX'}
# {'ID': '16', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '17', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': '16', 'POS_TAG': 'PROPN'}
# {'ID': '2', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '3', 'WORD': '17वीं', 'POS_TAG': 'PROPN'}
# {'ID': '4', 'WORD': 'SawAbxI', 'POS_TAG': 'PROPN'}
# {'ID': '5', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '6', 'WORD': 'buMxelA', 'POS_TAG': 'PROPN'}
# {'ID': '7', 'WORD': 'SAsakoM', 'POS_TAG': 'NOUN'}
# {'ID': '8', 'WORD': 'xvArA', 'POS_TAG': 'ADP'}
# {'ID': '9', 'WORD': 'banavAI', 'POS_TAG': 'VERB'}
# {'ID': '10', 'WORD': 'gaI', 'POS_TAG': 'AUX'}
# {'ID': '11', 'WORD': 'ye', 'POS_TAG': 'DET'}
# {'ID': '12', 'WORD': 'imAraweM', 'POS_TAG': 'NOUN'}
# {'ID': '13', 'WORD': 'prAcIna', 'POS_TAG': 'ADJ'}
# {'ID': '14', 'WORD': 'vEBava', 'POS_TAG': 'NOUN'}
# {'ID': '15', 'WORD': 'ko', 'POS_TAG': 'ADP'}
# {'ID': '16', 'WORD': 'bayAz', 'POS_TAG': 'NOUN'}
# {'ID': '17', 'WORD': 'karawI', 'POS_TAG': 'VERB'}
# {'ID': '18', 'WORD': 'hEM', 'POS_TAG': 'AUX'}
# {'ID': '19', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'oraCA', 'POS_TAG': 'PROPN'}
# {'ID': '2', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '3', 'WORD': '16वीं', 'POS_TAG': 'PROPN'}
# {'ID': '4', 'WORD': 'SawAbxI', 'POS_TAG': 'PROPN'}
# {'ID': '5', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '6', 'WORD': 'buMxelA', 'POS_TAG': 'PROPN'}
# {'ID': '7', 'WORD': 'rAjapUwa', 'POS_TAG': 'NOUN'}
# {'ID': '8', 'WORD': 'ruxra', 'POS_TAG': 'PROPN'}
# {'ID': '9', 'WORD': 'prawApa', 'POS_TAG': 'PROPN'}
# {'ID': '10', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '11', 'WORD': 'xvArA', 'POS_TAG': 'ADP'}
# {'ID': '12', 'WORD': 'basAyA', 'POS_TAG': 'VERB'}
# {'ID': '13', 'WORD': 'gayA', 'POS_TAG': 'AUX'}
# {'ID': '14', 'WORD': 'WA', 'POS_TAG': 'AUX'}
# {'ID': '15', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'unake', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'Age', 'POS_TAG': 'ADP'}
# {'ID': '3', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'rAjAoM', 'POS_TAG': 'NOUN'}
# {'ID': '5', 'WORD': 'ne', 'POS_TAG': 'ADP'}
# {'ID': '6', 'WORD': 'SAnaxAra', 'POS_TAG': 'ADJ'}
# {'ID': '7', 'WORD': 'imAraweM', 'POS_TAG': 'NOUN'}
# {'ID': '8', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '9', 'WORD': 'Bavana', 'POS_TAG': 'NOUN'}
# {'ID': '10', 'WORD': 'banavAkara', 'POS_TAG': 'VERB'}
# {'ID': '11', 'WORD': 'isakI', 'POS_TAG': 'PRON'}
# {'ID': '12', 'WORD': 'SAna', 'POS_TAG': 'NOUN'}
# {'ID': '13', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '14', 'WORD': 'cAra', 'POS_TAG': 'NUM'}
# {'ID': '15', 'WORD': 'cAzxa', 'POS_TAG': 'NOUN'}
# {'ID': '16', 'WORD': 'lagA', 'POS_TAG': 'VERB'}
# {'ID': '17', 'WORD': 'xie', 'POS_TAG': 'AUX'}
# {'ID': '18', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'jinameM', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'rAjA', 'POS_TAG': 'NOUN'}
# {'ID': '3', 'WORD': 'bIra', 'POS_TAG': 'PROPN'}
# {'ID': '4', 'WORD': 'siMha', 'POS_TAG': 'PROPN'}
# {'ID': '5', 'WORD': 'jUxeva', 'POS_TAG': 'PROPN'}
# {'ID': '6', 'WORD': 'kA', 'POS_TAG': 'ADP'}
# {'ID': '7', 'WORD': 'nAma', 'POS_TAG': 'NOUN'}
# {'ID': '8', 'WORD': 'pramuKa', 'POS_TAG': 'ADJ'}
# {'ID': '9', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '10', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'maMxiroM', 'POS_TAG': 'NOUN'}
# {'ID': '2', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '3', 'WORD': 'mahaloM', 'POS_TAG': 'NOUN'}
# {'ID': '4', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '5', 'WORD': 'buMxelA', 'POS_TAG': 'PROPN'}
# {'ID': '6', 'WORD': 'kalA', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': 'kI', 'POS_TAG': 'ADP'}
# {'ID': '8', 'WORD': 'KUbasUrawa', 'POS_TAG': 'ADJ'}
# {'ID': '9', 'WORD': 'kalAkArI', 'POS_TAG': 'NOUN'}
# {'ID': '10', 'WORD': 'xeKawe', 'POS_TAG': 'VERB'}
# {'ID': '11', 'WORD': 'hI', 'POS_TAG': 'PART'}
# {'ID': '12', 'WORD': 'banawI', 'POS_TAG': 'VERB'}
# {'ID': '13', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '14', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'lakRmInArAyaNa', 'POS_TAG': 'PROPN'}
# {'ID': '2', 'WORD': 'maMxira', 'POS_TAG': 'PROPN'}
# {'ID': '3', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '4', 'WORD': 'rAjamahala', 'POS_TAG': 'NOUN'}
# {'ID': '5', 'WORD': 'kI', 'POS_TAG': 'ADP'}
# {'ID': '6', 'WORD': 'xIvAreM', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '8', 'WORD': 'CawoM', 'POS_TAG': 'NOUN'}
# {'ID': '9', 'WORD': 'kI', 'POS_TAG': 'ADP'}
# {'ID': '10', 'WORD': 'kalAwmakawA', 'POS_TAG': 'NOUN'}
# {'ID': '11', 'WORD': 'yahAz', 'POS_TAG': 'PRON'}
# {'ID': '12', 'WORD': 'kI', 'POS_TAG': 'ADP'}
# {'ID': '13', 'WORD': 'samqxXi', 'POS_TAG': 'NOUN'}
# {'ID': '14', 'WORD': 'kI', 'POS_TAG': 'ADP'}
# {'ID': '15', 'WORD': 'kahAnI', 'POS_TAG': 'NOUN'}
# {'ID': '16', 'WORD': 'kahawIM', 'POS_TAG': 'VERB'}
# {'ID': '17', 'WORD': 'hEM', 'POS_TAG': 'AUX'}
# {'ID': '18', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'yaha', 'POS_TAG': 'DET'}
# {'ID': '2', 'WORD': 'mahala', 'POS_TAG': 'NOUN'}
# {'ID': '3', 'WORD': 'rAjA', 'POS_TAG': 'NOUN'}
# {'ID': '4', 'WORD': 'bIra', 'POS_TAG': 'PROPN'}
# {'ID': '5', 'WORD': 'siMha', 'POS_TAG': 'PROPN'}
# {'ID': '6', 'WORD': 'jUxeva', 'POS_TAG': 'PROPN'}
# {'ID': '7', 'WORD': 'ne', 'POS_TAG': 'ADP'}
# {'ID': '8', 'WORD': '17वीं', 'POS_TAG': 'PROPN'}
# {'ID': '9', 'WORD': 'SawAbxI', 'POS_TAG': 'PROPN'}
# {'ID': '10', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '11', 'WORD': 'jahAzgIra', 'POS_TAG': 'PROPN'}
# {'ID': '12', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '13', 'WORD': 'oraCA', 'POS_TAG': 'PROPN'}
# {'ID': '14', 'WORD': 'Ane', 'POS_TAG': 'VERB'}
# {'ID': '15', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '16', 'WORD': 'pahale', 'POS_TAG': 'ADV'}
# {'ID': '17', 'WORD': 'banavAyA', 'POS_TAG': 'VERB'}
# {'ID': '18', 'WORD': 'WA', 'POS_TAG': 'AUX'}
# {'ID': '19', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'isakI', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'majabUwa', 'POS_TAG': 'ADJ'}
# {'ID': '3', 'WORD': 'xIvAroM', 'POS_TAG': 'NOUN'}
# {'ID': '4', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '5', 'WORD': 'sAWa', 'POS_TAG': 'ADP'}
# {'ID': '6', 'WORD': 'nAjukI', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '8', 'WORD': 'banI', 'POS_TAG': 'VERB'}
# {'ID': '9', 'WORD': 'huI', 'POS_TAG': 'AUX'}
# {'ID': '10', 'WORD': 'CawariyAz', 'POS_TAG': 'NOUN'}
# {'ID': '11', 'WORD': 'kamAla', 'POS_TAG': 'NOUN'}
# {'ID': '12', 'WORD': 'kA', 'POS_TAG': 'ADP'}
# {'ID': '13', 'WORD': 'saMwulana', 'POS_TAG': 'NOUN'}
# {'ID': '14', 'WORD': 'banAwI', 'POS_TAG': 'VERB'}
# {'ID': '15', 'WORD': 'hEM', 'POS_TAG': 'AUX'}
# {'ID': '16', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '17', 'WORD': 'isase', 'POS_TAG': 'PRON'}
# {'ID': '18', 'WORD': 'pUrI', 'POS_TAG': 'ADJ'}
# {'ID': '19', 'WORD': 'imArawa', 'POS_TAG': 'NOUN'}
# {'ID': '20', 'WORD': 'awyaMwa', 'POS_TAG': 'ADV'}
# {'ID': '21', 'WORD': 'samqxXipUrNa', 'POS_TAG': 'ADJ'}
# {'ID': '22', 'WORD': 'praBAva', 'POS_TAG': 'NOUN'}
# {'ID': '23', 'WORD': 'xewI', 'POS_TAG': 'VERB'}
# {'ID': '24', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '25', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'cawurBuja', 'POS_TAG': 'NOUN'}
# {'ID': '2', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '3', 'WORD': 'AkAra', 'POS_TAG': 'NOUN'}
# {'ID': '4', 'WORD': 'kA', 'POS_TAG': 'ADP'}
# {'ID': '5', 'WORD': 'yaha', 'POS_TAG': 'DET'}
# {'ID': '6', 'WORD': 'mahala', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': '17वीं', 'POS_TAG': 'PROPN'}
# {'ID': '8', 'WORD': 'SawAbxI', 'POS_TAG': 'PROPN'}
# {'ID': '9', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '10', 'WORD': 'maXukara', 'POS_TAG': 'PROPN'}
# {'ID': '11', 'WORD': 'SAha', 'POS_TAG': 'PROPN'}
# {'ID': '12', 'WORD': 'ne', 'POS_TAG': 'ADP'}
# {'ID': '13', 'WORD': 'banavAyA', 'POS_TAG': 'VERB'}
# {'ID': '14', 'WORD': 'WA', 'POS_TAG': 'AUX'}
# {'ID': '15', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'aMxara', 'POS_TAG': 'ADV'}
# {'ID': '2', 'WORD': 'XArmikawA', 'POS_TAG': 'NOUN'}
# {'ID': '3', 'WORD': 'ko', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'lie', 'POS_TAG': 'VERB'}
# {'ID': '5', 'WORD': 'hue', 'POS_TAG': 'AUX'}
# {'ID': '6', 'WORD': 'SoKa', 'POS_TAG': 'ADJ'}
# {'ID': '7', 'WORD': 'raMgoM', 'POS_TAG': 'NOUN'}
# {'ID': '8', 'WORD': 'kI', 'POS_TAG': 'ADP'}
# {'ID': '9', 'WORD': 'anoKI', 'POS_TAG': 'ADJ'}
# {'ID': '10', 'WORD': 'Silpa', 'POS_TAG': 'NOUN'}
# {'ID': '11', 'WORD': 'kalAkqwiyAz', 'POS_TAG': 'NOUN'}
# {'ID': '12', 'WORD': 'hEM', 'POS_TAG': 'AUX'}
# {'ID': '13', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'yaha', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'xo', 'POS_TAG': 'NUM'}
# {'ID': '3', 'WORD': 'kqwrima', 'POS_TAG': 'ADJ'}
# {'ID': '4', 'WORD': 'wAlAboM', 'POS_TAG': 'NOUN'}
# {'ID': '5', 'WORD': 'muMja', 'POS_TAG': 'PROPN'}
# {'ID': '6', 'WORD': 'wAlAba', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '8', 'WORD': 'kApura', 'POS_TAG': 'PROPN'}
# {'ID': '9', 'WORD': 'wAlAba', 'POS_TAG': 'NOUN'}
# {'ID': '10', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '11', 'WORD': 'bIca', 'POS_TAG': 'ADP'}
# {'ID': '12', 'WORD': 'banA', 'POS_TAG': 'VERB'}
# {'ID': '13', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '14', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'saMBavawaH', 'POS_TAG': 'ADV'}
# {'ID': '2', 'WORD': 'yaha', 'POS_TAG': 'PRON'}
# {'ID': '3', 'WORD': 'sulwAna', 'POS_TAG': 'NOUN'}
# {'ID': '4', 'WORD': 'gayAsuxxIna', 'POS_TAG': 'PROPN'}
# {'ID': '5', 'WORD': 'KilajI', 'POS_TAG': 'PROPN'}
# {'ID': '6', 'WORD': 'ne', 'POS_TAG': 'ADP'}
# {'ID': '7', 'WORD': 'badZe', 'POS_TAG': 'ADJ'}
# {'ID': '8', 'WORD': 'harama', 'POS_TAG': 'NOUN'}
# {'ID': '9', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '10', 'WORD': 'rUpa', 'POS_TAG': 'ADP'}
# {'ID': '11', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '12', 'WORD': 'banavAyA', 'POS_TAG': 'VERB'}
# {'ID': '13', 'WORD': 'WA', 'POS_TAG': 'AUX'}
# {'ID': '14', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'isake', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'Kule', 'POS_TAG': 'ADJ'}
# {'ID': '3', 'WORD': 'galiyAre', 'POS_TAG': 'NOUN'}
# {'ID': '4', 'WORD': ',', 'POS_TAG': 'PUNCT'}
# {'ID': '5', 'WORD': 'bAhara', 'POS_TAG': 'ADV'}
# {'ID': '6', 'WORD': 'nikalI', 'POS_TAG': 'VERB'}
# {'ID': '7', 'WORD': 'huI', 'POS_TAG': 'AUX'}
# {'ID': '8', 'WORD': 'bAlakanI', 'POS_TAG': 'NOUN'}
# {'ID': '9', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '10', 'WORD': 'KUbasUrawa', 'POS_TAG': 'ADJ'}
# {'ID': '11', 'WORD': 'Cawa', 'POS_TAG': 'NOUN'}
# {'ID': '12', 'WORD': 'SAhI', 'POS_TAG': 'ADJ'}
# {'ID': '13', 'WORD': 'SOka', 'POS_TAG': 'NOUN'}
# {'ID': '14', 'WORD': 'ko', 'POS_TAG': 'ADP'}
# {'ID': '15', 'WORD': 'AsAnI', 'POS_TAG': 'NOUN'}
# {'ID': '16', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '17', 'WORD': 'bayAz', 'POS_TAG': 'NOUN'}
# {'ID': '18', 'WORD': 'karawe', 'POS_TAG': 'VERB'}
# {'ID': '19', 'WORD': 'hEM', 'POS_TAG': 'AUX'}
# {'ID': '20', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'rAwa', 'POS_TAG': 'NOUN'}
# {'ID': '2', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '3', 'WORD': 'samaya', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'ise', 'POS_TAG': 'PRON'}
# {'ID': '5', 'WORD': 'wavelI', 'POS_TAG': 'PROPN'}
# {'ID': '6', 'WORD': 'mahala', 'POS_TAG': 'PROPN'}
# {'ID': '7', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '8', 'WORD': 'nihAranA', 'POS_TAG': 'VERB'}
# {'ID': '9', 'WORD': 'bahuwa', 'POS_TAG': 'ADV'}
# {'ID': '10', 'WORD': 'suKaxAyI', 'POS_TAG': 'ADJ'}
# {'ID': '11', 'WORD': 'hE', 'POS_TAG': 'VERB'}
# {'ID': '12', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'yaha', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'xarSakoM', 'POS_TAG': 'NOUN'}
# {'ID': '3', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'lie', 'POS_TAG': 'ADP'}
# {'ID': '5', 'WORD': 'bETaka', 'POS_TAG': 'NOUN'}
# {'ID': '6', 'WORD': 'vyavasWA', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '8', 'WORD': 'rUpa', 'POS_TAG': 'ADP'}
# {'ID': '9', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '10', 'WORD': 'banAyA', 'POS_TAG': 'VERB'}
# {'ID': '11', 'WORD': 'gayA', 'POS_TAG': 'AUX'}
# {'ID': '12', 'WORD': 'WA', 'POS_TAG': 'AUX'}
# {'ID': '13', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'isake', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'Asa', 'POS_TAG': 'NOUN'}
# {'ID': '3', 'WORD': '-', 'POS_TAG': 'PUNCT'}
# {'ID': '4', 'WORD': 'pAsa', 'POS_TAG': 'ADP'}
# {'ID': '5', 'WORD': 'kI', 'POS_TAG': 'ADP'}
# {'ID': '6', 'WORD': 'xIvAreM', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': 'kuCa', 'POS_TAG': 'DET'}
# {'ID': '8', 'WORD': 'JukI', 'POS_TAG': 'VERB'}
# {'ID': '9', 'WORD': 'huI', 'POS_TAG': 'AUX'}
# {'ID': '10', 'WORD': 'sI', 'POS_TAG': 'PART'}
# {'ID': '11', 'WORD': 'hEM', 'POS_TAG': 'AUX'}
# {'ID': '12', 'WORD': 'jisake', 'POS_TAG': 'PRON'}
# {'ID': '13', 'WORD': 'kAraNa', 'POS_TAG': 'ADP'}
# {'ID': '14', 'WORD': 'ise', 'POS_TAG': 'PRON'}
# {'ID': '15', 'WORD': 'hiMdolA', 'POS_TAG': 'PROPN'}
# {'ID': '16', 'WORD': 'mahala', 'POS_TAG': 'PROPN'}
# {'ID': '17', 'WORD': 'kahA', 'POS_TAG': 'VERB'}
# {'ID': '18', 'WORD': 'jAwA', 'POS_TAG': 'AUX'}
# {'ID': '19', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '20', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'baluA', 'POS_TAG': 'PROPN'}
# {'ID': '2', 'WORD': 'pawWaroM', 'POS_TAG': 'NOUN'}
# {'ID': '3', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'nakkASI', 'POS_TAG': 'NOUN'}
# {'ID': '5', 'WORD': 'kA', 'POS_TAG': 'ADP'}
# {'ID': '6', 'WORD': 'nAyAba', 'POS_TAG': 'ADJ'}
# {'ID': '7', 'WORD': 'namUnA', 'POS_TAG': 'NOUN'}
# {'ID': '8', 'WORD': 'yahAz', 'POS_TAG': 'PRON'}
# {'ID': '9', 'WORD': 'xeKane', 'POS_TAG': 'VERB'}
# {'ID': '10', 'WORD': 'ko', 'POS_TAG': 'ADP'}
# {'ID': '11', 'WORD': 'milawA', 'POS_TAG': 'VERB'}
# {'ID': '12', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '13', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'yahAz', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '3', 'WORD': 'KUbasUrawa', 'POS_TAG': 'ADJ'}
# {'ID': '4', 'WORD': 'swaMBa', 'POS_TAG': 'NOUN'}
# {'ID': '5', 'WORD': 'mana', 'POS_TAG': 'NOUN'}
# ...
# {'ID': '8', 'WORD': 'hEM', 'POS_TAG': 'AUX'}
# {'ID': '9', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'isake', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'alAvA', 'POS_TAG': 'ADP'}
# {'ID': '3', 'WORD': 'alaga', 'POS_TAG': 'ADJ'}
# {'ID': '4', 'WORD': '-', 'POS_TAG': 'PUNCT'}
# {'ID': '5', 'WORD': 'alaga', 'POS_TAG': 'ADJ'}
# {'ID': '6', 'WORD': 'xeSoM', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '8', 'WORD': 'maMxiroM', 'POS_TAG': 'NOUN'}
# {'ID': '9', 'WORD': 'kI', 'POS_TAG': 'ADP'}
# {'ID': '10', 'WORD': 'XarmaSAlA', 'POS_TAG': 'NOUN'}
# {'ID': '11', 'WORD': 'BI', 'POS_TAG': 'PART'}
# {'ID': '12', 'WORD': 'hEM', 'POS_TAG': 'AUX'}
# {'ID': '13', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'bOxXa', 'POS_TAG': 'ADJ'}
# {'ID': '2', 'WORD': 'BikRuoM', 'POS_TAG': 'NOUN'}
# {'ID': '3', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'lie', 'POS_TAG': 'ADP'}
# {'ID': '5', 'WORD': 'kuCa', 'POS_TAG': 'DET'}
# {'ID': '6', 'WORD': 'maMxiroM', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '8', 'WORD': 'vihAra', 'POS_TAG': 'NOUN'}
# {'ID': '9', 'WORD': 'kI', 'POS_TAG': 'ADP'}
# {'ID': '10', 'WORD': 'vyavasWA', 'POS_TAG': 'NOUN'}
# {'ID': '11', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '12', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'yuga', 'POS_TAG': 'NOUN'}
# {'ID': '2', 'WORD': '-', 'POS_TAG': 'PUNCT'}
# {'ID': '3', 'WORD': 'yugAMwara', 'POS_TAG': 'NOUN'}
# {'ID': '4', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '5', 'WORD': 'uwwarAKaMda', 'POS_TAG': 'PROPN'}
# {'ID': '6', 'WORD': 'BArawIyoM', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '8', 'WORD': 'lie', 'POS_TAG': 'ADP'}
# {'ID': '9', 'WORD': 'AXyAwmika', 'POS_TAG': 'ADJ'}
# {'ID': '10', 'WORD': 'SaraNasWala', 'POS_TAG': 'NOUN'}
# {'ID': '11', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '12', 'WORD': 'SAMwi', 'POS_TAG': 'NOUN'}
# {'ID': '13', 'WORD': 'praxAwA', 'POS_TAG': 'NOUN'}
# {'ID': '14', 'WORD': 'rahA', 'POS_TAG': 'VERB'}
# {'ID': '15', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '16', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'prAgEwihAsika', 'POS_TAG': 'ADJ'}
# {'ID': '2', 'WORD': 'kAla', 'POS_TAG': 'NOUN'}
# {'ID': '3', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'qRi', 'POS_TAG': 'NOUN'}
# {'ID': '5', 'WORD': '-', 'POS_TAG': 'PUNCT'}
# {'ID': '6', 'WORD': 'muniyoM', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '8', 'WORD': 'sAXaka', 'POS_TAG': 'NOUN'}
# {'ID': '9', 'WORD': '","', 'POS_TAG': 'PUNCT'}
# {'ID': '10', 'WORD': 'parivrAjakoM', 'POS_TAG': 'NOUN'}
# {'ID': '11', 'WORD': 'ko', 'POS_TAG': 'ADP'}
# {'ID': '12', 'WORD': 'yaha', 'POS_TAG': 'PRON'}
# {'ID': '13', 'WORD': 'AkarRiwa', 'POS_TAG': 'ADJ'}
# {'ID': '14', 'WORD': 'karawA', 'POS_TAG': 'VERB'}
# {'ID': '15', 'WORD': 'A', 'POS_TAG': 'AUX'}
# {'ID': '16', 'WORD': 'rahA', 'POS_TAG': 'AUX'}
# {'ID': '17', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '18', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'himAlaya', 'POS_TAG': 'PROPN'}
# {'ID': '2', 'WORD': 'prakqwi', 'POS_TAG': 'NOUN'}
# {'ID': '3', 'WORD': 'kA', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'mahAmaMxira', 'POS_TAG': 'NOUN'}
# {'ID': '5', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '6', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'yahAz', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'kexAranAWa', 'POS_TAG': 'PROPN'}
# {'ID': '3', 'WORD': 'wIrWa', 'POS_TAG': 'NOUN'}
# {'ID': '4', 'WORD': 'uwwarAKaMda', 'POS_TAG': 'PROPN'}
# {'ID': '5', 'WORD': 'kA', 'POS_TAG': 'ADP'}
# {'ID': '6', 'WORD': 'mahawvapUrNa', 'POS_TAG': 'ADJ'}
# {'ID': '7', 'WORD': 'sWala', 'POS_TAG': 'NOUN'}
# {'ID': '8', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '9', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'yahAz', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'jAwe', 'POS_TAG': 'VERB'}
# {'ID': '3', 'WORD': 'samaya', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'pEroM', 'POS_TAG': 'NOUN'}
# {'ID': '5', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '6', 'WORD': 'nIce', 'POS_TAG': 'ADP'}
# {'ID': '7', 'WORD': 'yawra', 'POS_TAG': 'PRON'}
# {'ID': '8', 'WORD': '-', 'POS_TAG': 'PUNCT'}
# {'ID': '9', 'WORD': 'wawra', 'POS_TAG': 'PRON'}
# {'ID': '10', 'WORD': 'hima', 'POS_TAG': 'NOUN'}
# {'ID': '11', 'WORD': 'rASi', 'POS_TAG': 'NOUN'}
# {'ID': '12', 'WORD': 'KisakawI', 'POS_TAG': 'VERB'}
# {'ID': '13', 'WORD': 'xiKAI', 'POS_TAG': 'VERB'}
# {'ID': '14', 'WORD': 'padZawI', 'POS_TAG': 'AUX'}
# {'ID': '15', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '16', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'barPa', 'POS_TAG': 'NOUN'}
# {'ID': '2', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '3', 'WORD': 'pAsa', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'hI', 'POS_TAG': 'PART'}
# {'ID': '5', 'WORD': 'awyaMwa', 'POS_TAG': 'ADV'}
# {'ID': '6', 'WORD': 'mAxaka', 'POS_TAG': 'ADJ'}
# {'ID': '7', 'WORD': 'sugaMXa', 'POS_TAG': 'NOUN'}
# {'ID': '8', 'WORD': 'vAle', 'POS_TAG': 'ADP'}
# {'ID': '9', 'WORD': 'siraMgA', 'POS_TAG': 'PROPN'}
# {'ID': '10', 'WORD': 'puRpakuMja', 'POS_TAG': 'NOUN'}
# {'ID': '11', 'WORD': 'milane', 'POS_TAG': 'VERB'}
# {'ID': '12', 'WORD': 'lagawe', 'POS_TAG': 'AUX'}
# {'ID': '13', 'WORD': 'hEM', 'POS_TAG': 'AUX'}
# {'ID': '14', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'inake', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'samApwa', 'POS_TAG': 'ADJ'}
# {'ID': '3', 'WORD': 'hone', 'POS_TAG': 'VERB'}
# {'ID': '4', 'WORD': 'para', 'POS_TAG': 'ADP'}
# {'ID': '5', 'WORD': 'harI', 'POS_TAG': 'ADJ'}
# {'ID': '6', 'WORD': 'bugyAla', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': "'", 'POS_TAG': 'PUNCT'}
# {'ID': '8', 'WORD': 'xUba', 'POS_TAG': 'NOUN'}
# {'ID': '9', 'WORD': "'", 'POS_TAG': 'PUNCT'}
# {'ID': '10', 'WORD': 'milawI', 'POS_TAG': 'VERB'}
# {'ID': '11', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '12', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'isake', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'paScAwa', 'POS_TAG': 'ADP'}
# {'ID': '3', 'WORD': 'kexAranAWa', 'POS_TAG': 'PROPN'}
# {'ID': '4', 'WORD': 'kA', 'POS_TAG': 'ADP'}
# {'ID': '5', 'WORD': 'himanaxa', 'POS_TAG': 'NOUN'}
# {'ID': '6', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '7', 'WORD': 'usase', 'POS_TAG': 'PRON'}
# {'ID': '8', 'WORD': 'nikalane', 'POS_TAG': 'VERB'}
# {'ID': '9', 'WORD': 'vAlI', 'POS_TAG': 'ADP'}
# {'ID': '10', 'WORD': 'maMxAkinI', 'POS_TAG': 'PROPN'}
# {'ID': '11', 'WORD': 'apane', 'POS_TAG': 'PRON'}
# {'ID': '12', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '13', 'WORD': 'asaMKya', 'POS_TAG': 'DET'}
# {'ID': '14', 'WORD': 'pARANa', 'POS_TAG': 'NOUN'}
# {'ID': '15', 'WORD': 'KaMdoM', 'POS_TAG': 'NOUN'}
# {'ID': '16', 'WORD': 'ko', 'POS_TAG': 'ADP'}
# {'ID': '17', 'WORD': 'PodZakara', 'POS_TAG': 'VERB'}
# {'ID': '18', 'WORD': 'nikale', 'POS_TAG': 'VERB'}
# {'ID': '19', 'WORD': 'JaranoM', 'POS_TAG': 'NOUN'}
# {'ID': '20', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '21', 'WORD': 'PavvAroM', 'POS_TAG': 'NOUN'}
# {'ID': '22', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '23', 'WORD': 'jala', 'POS_TAG': 'NOUN'}
# {'ID': '24', 'WORD': 'ko', 'POS_TAG': 'ADP'}
# {'ID': '25', 'WORD': 'samete', 'POS_TAG': 'VERB'}
# {'ID': '26', 'WORD': 'uxxAma', 'POS_TAG': 'ADJ'}
# {'ID': '27', 'WORD': 'gawi', 'POS_TAG': 'NOUN'}
# {'ID': '28', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '29', 'WORD': 'pravAhiwa', 'POS_TAG': 'ADJ'}
# {'ID': '30', 'WORD': 'howI', 'POS_TAG': 'VERB'}
# {'ID': '31', 'WORD': 'xiKAI', 'POS_TAG': 'VERB'}
# {'ID': '32', 'WORD': 'xewI', 'POS_TAG': 'AUX'}
# {'ID': '33', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '34', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'ina', 'POS_TAG': 'DET'}
# {'ID': '2', 'WORD': 'sabake', 'POS_TAG': 'PRON'}
# {'ID': '3', 'WORD': 'Upara', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'kexAranAWa', 'POS_TAG': 'PROPN'}
# {'ID': '5', 'WORD': 'kA', 'POS_TAG': 'ADP'}
# {'ID': '6', 'WORD': '6', 'POS_TAG': 'NUM'}
# {'ID': '7', 'WORD': 'hajAra', 'POS_TAG': 'NUM'}
# {'ID': '8', 'WORD': '940', 'POS_TAG': 'NUM'}
# {'ID': '9', 'WORD': 'mItara', 'POS_TAG': 'NOUN'}
# {'ID': '10', 'WORD': 'UzcA', 'POS_TAG': 'ADJ'}
# {'ID': '11', 'WORD': 'himaSiKara', 'POS_TAG': 'NOUN'}
# {'ID': '12', 'WORD': 'EsA', 'POS_TAG': 'PRON'}
# {'ID': '13', 'WORD': 'xiKAI', 'POS_TAG': 'VERB'}
# {'ID': '14', 'WORD': 'xewA', 'POS_TAG': 'AUX'}
# {'ID': '15', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '16', 'WORD': '","', 'POS_TAG': 'PUNCT'}
# {'ID': '17', 'WORD': 'mAno', 'POS_TAG': 'ADV'}
# {'ID': '18', 'WORD': 'svarga', 'POS_TAG': 'NOUN'}
# {'ID': '19', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '20', 'WORD': 'rahane', 'POS_TAG': 'VERB'}
# {'ID': '21', 'WORD': 'vAle', 'POS_TAG': 'AUX'}
# {'ID': '22', 'WORD': 'xevawAoM', 'POS_TAG': 'NOUN'}
# {'ID': '23', 'WORD': 'kA', 'POS_TAG': 'ADP'}
# {'ID': '24', 'WORD': 'mqwyuloka', 'POS_TAG': 'NOUN'}
# {'ID': '25', 'WORD': 'ko', 'POS_TAG': 'ADP'}
# {'ID': '26', 'WORD': 'JAzkane', 'POS_TAG': 'VERB'}
# {'ID': '27', 'WORD': 'kA', 'POS_TAG': 'ADP'}
# {'ID': '28', 'WORD': 'yaha', 'POS_TAG': 'PRON'}
# {'ID': '29', 'WORD': 'JaroKA', 'POS_TAG': 'NOUN'}
# {'ID': '30', 'WORD': 'ho', 'POS_TAG': 'VERB'}
# {'ID': '31', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'qRikeSa', 'POS_TAG': 'PROPN'}
# {'ID': '2', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '3', 'WORD': 'kexAranAWa', 'POS_TAG': 'PROPN'}
# {'ID': '4', 'WORD': 'kI', 'POS_TAG': 'ADP'}
# {'ID': '5', 'WORD': 'xUrI', 'POS_TAG': 'NOUN'}
# {'ID': '6', 'WORD': '223', 'POS_TAG': 'NUM'}
# {'ID': '7', 'WORD': 'kimI', 'POS_TAG': 'NOUN'}
# {'ID': '8', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '9', 'WORD': '","', 'POS_TAG': 'PUNCT'}
# {'ID': '10', 'WORD': 'jisameM', 'POS_TAG': 'PRON'}
# {'ID': '11', 'WORD': 'aMwima', 'POS_TAG': 'ADJ'}
# {'ID': '12', 'WORD': 'xasa', 'POS_TAG': 'NUM'}
# {'ID': '13', 'WORD': 'kimI', 'POS_TAG': 'NOUN'}
# {'ID': '14', 'WORD': 'kA', 'POS_TAG': 'ADP'}
# {'ID': '15', 'WORD': 'aMSa', 'POS_TAG': 'NOUN'}
# {'ID': '16', 'WORD': 'jo', 'POS_TAG': 'PRON'}
# {'ID': '17', 'WORD': 'gOrIkuMda', 'POS_TAG': 'PROPN'}
# {'ID': '18', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '19', 'WORD': 'kexAranAWa', 'POS_TAG': 'PROPN'}
# {'ID': '20', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '21', 'WORD': 'vaha', 'POS_TAG': 'PRON'}
# {'ID': '22', 'WORD': 'pExala', 'POS_TAG': 'NOUN'}
# {'ID': '23', 'WORD': '","', 'POS_TAG': 'PUNCT'}
# {'ID': '24', 'WORD': 'GodZe', 'POS_TAG': 'NOUN'}
# {'ID': '25', 'WORD': 'yA', 'POS_TAG': 'CCONJ'}
# {'ID': '26', 'WORD': 'pAlakI', 'POS_TAG': 'NOUN'}
# {'ID': '27', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '28', 'WORD': 'jAnA', 'POS_TAG': 'VERB'}
# {'ID': '29', 'WORD': 'padZawA', 'POS_TAG': 'AUX'}
# {'ID': '30', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '31', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'yaha', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'uwwarAKaMda', 'POS_TAG': 'PROPN'}
# {'ID': '3', 'WORD': 'kA', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'sabase', 'POS_TAG': 'ADV'}
# {'ID': '5', 'WORD': 'viSAla', 'POS_TAG': 'ADJ'}
# {'ID': '6', 'WORD': 'Siva', 'POS_TAG': 'PROPN'}
# {'ID': '7', 'WORD': 'maMxira', 'POS_TAG': 'NOUN'}
# {'ID': '8', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '9', 'WORD': '","', 'POS_TAG': 'PUNCT'}
# {'ID': '10', 'WORD': 'jo', 'POS_TAG': 'PRON'}
# {'ID': '11', 'WORD': 'katavAz', 'POS_TAG': 'ADJ'}
# {'ID': '12', 'WORD': 'pawWaroM', 'POS_TAG': 'NOUN'}
# {'ID': '13', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '14', 'WORD': 'viSAla', 'POS_TAG': 'ADJ'}
# {'ID': '15', 'WORD': 'SilAKaMdoM', 'POS_TAG': 'NOUN'}
# {'ID': '16', 'WORD': 'ko', 'POS_TAG': 'ADP'}
# {'ID': '17', 'WORD': 'jodZakara', 'POS_TAG': 'VERB'}
# {'ID': '18', 'WORD': 'banAyA', 'POS_TAG': 'VERB'}
# {'ID': '19', 'WORD': 'gayA', 'POS_TAG': 'AUX'}
# {'ID': '20', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '21', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'ye', 'POS_TAG': 'DET'}
# {'ID': '2', 'WORD': 'SilAKaMda', 'POS_TAG': 'NOUN'}
# {'ID': '3', 'WORD': 'BUre', 'POS_TAG': 'ADJ'}
# {'ID': '4', 'WORD': 'raMga', 'POS_TAG': 'NOUN'}
# {'ID': '5', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '6', 'WORD': 'hEM', 'POS_TAG': 'AUX'}
# {'ID': '7', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'maMxira', 'POS_TAG': 'NOUN'}
# {'ID': '2', 'WORD': 'lagaBaga', 'POS_TAG': 'PART'}
# {'ID': '3', 'WORD': '6', 'POS_TAG': 'NUM'}
# {'ID': '4', 'WORD': 'Puta', 'POS_TAG': 'NOUN'}
# {'ID': '5', 'WORD': 'Uzce', 'POS_TAG': 'ADJ'}
# {'ID': '6', 'WORD': 'cabUware', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': 'para', 'POS_TAG': 'ADP'}
# {'ID': '8', 'WORD': 'banA', 'POS_TAG': 'VERB'}
# {'ID': '9', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '10', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'maMxira', 'POS_TAG': 'NOUN'}
# {'ID': '2', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '3', 'WORD': 'garBagqha', 'POS_TAG': 'NOUN'}
# {'ID': '4', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '5', 'WORD': 'arXA', 'POS_TAG': 'NOUN'}
# {'ID': '6', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '7', 'WORD': 'pAsa', 'POS_TAG': 'ADP'}
# {'ID': '8', 'WORD': 'cAroM', 'POS_TAG': 'NUM'}
# {'ID': '9', 'WORD': 'konoM', 'POS_TAG': 'NOUN'}
# {'ID': '10', 'WORD': 'para', 'POS_TAG': 'ADP'}
# {'ID': '11', 'WORD': 'cAra', 'POS_TAG': 'NUM'}
# {'ID': '12', 'WORD': 'suxqDZa', 'POS_TAG': 'ADJ'}
# {'ID': '13', 'WORD': 'pARANa', 'POS_TAG': 'NOUN'}
# {'ID': '14', 'WORD': 'swaMBa', 'POS_TAG': 'NOUN'}
# {'ID': '15', 'WORD': 'hEM', 'POS_TAG': 'AUX'}
# {'ID': '16', 'WORD': '","', 'POS_TAG': 'PUNCT'}
# {'ID': '17', 'WORD': 'jahAz', 'POS_TAG': 'PRON'}
# {'ID': '18', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '19', 'WORD': 'hokara', 'POS_TAG': 'VERB'}
# {'ID': '20', 'WORD': 'praxakRiNA', 'POS_TAG': 'NOUN'}
# {'ID': '21', 'WORD': 'howI', 'POS_TAG': 'VERB'}
# {'ID': '22', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '23', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'arXA', 'POS_TAG': 'NOUN'}
# {'ID': '2', 'WORD': '","', 'POS_TAG': 'PUNCT'}
# {'ID': '3', 'WORD': 'jo', 'POS_TAG': 'PRON'}
# {'ID': '4', 'WORD': 'cOkora', 'POS_TAG': 'NOUN'}
# {'ID': '5', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '6', 'WORD': '","', 'POS_TAG': 'PUNCT'}
# {'ID': '7', 'WORD': 'aMxara', 'POS_TAG': 'ADV'}
# {'ID': '8', 'WORD': 'se', 'POS_TAG': 'ADP'}
# {'ID': '9', 'WORD': 'polI', 'POS_TAG': 'ADJ'}
# {'ID': '10', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '11', 'WORD': 'Ora', 'POS_TAG': 'CCONJ'}
# {'ID': '12', 'WORD': 'apekRAkqwa', 'POS_TAG': 'ADV'}
# {'ID': '13', 'WORD': 'navIna', 'POS_TAG': 'ADJ'}
# {'ID': '14', 'WORD': 'banI', 'POS_TAG': 'VERB'}
# {'ID': '15', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '16', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'saBA', 'POS_TAG': 'NOUN'}
# {'ID': '2', 'WORD': 'maMdapa', 'POS_TAG': 'NOUN'}
# {'ID': '3', 'WORD': 'viSAla', 'POS_TAG': 'ADJ'}
# {'ID': '4', 'WORD': 'evaM', 'POS_TAG': 'CCONJ'}
# {'ID': '5', 'WORD': 'Bavya', 'POS_TAG': 'ADJ'}
# {'ID': '6', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '7', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'usakI', 'POS_TAG': 'PRON'}
# {'ID': '2', 'WORD': 'Cawa', 'POS_TAG': 'NOUN'}
# {'ID': '3', 'WORD': 'cAra', 'POS_TAG': 'NUM'}
# {'ID': '4', 'WORD': 'viSAla', 'POS_TAG': 'ADJ'}
# {'ID': '5', 'WORD': 'pARANa', 'POS_TAG': 'NOUN'}
# {'ID': '6', 'WORD': 'swaMBoM', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': 'para', 'POS_TAG': 'ADP'}
# {'ID': '8', 'WORD': 'tikI', 'POS_TAG': 'VERB'}
# {'ID': '9', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '10', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'gavAkRoM', 'POS_TAG': 'NOUN'}
# {'ID': '2', 'WORD': 'meM', 'POS_TAG': 'ADP'}
# {'ID': '3', 'WORD': 'ATa', 'POS_TAG': 'NUM'}
# {'ID': '4', 'WORD': 'puruRa', 'POS_TAG': 'ADJ'}
# {'ID': '5', 'WORD': 'pramANa', 'POS_TAG': 'ADJ'}
# {'ID': '6', 'WORD': 'mUrwiyAz', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': 'hEM', 'POS_TAG': 'AUX'}
# {'ID': '8', 'WORD': '","', 'POS_TAG': 'PUNCT'}
# {'ID': '9', 'WORD': 'jo', 'POS_TAG': 'PRON'}
# {'ID': '10', 'WORD': 'awyaMwa', 'POS_TAG': 'ADV'}
# {'ID': '11', 'WORD': 'kalAwmaka', 'POS_TAG': 'ADJ'}
# {'ID': '12', 'WORD': 'hEM', 'POS_TAG': 'AUX'}
# {'ID': '13', 'WORD': '.', 'POS_TAG': 'PUNCT'}
# {'ID': '1', 'WORD': 'maMxira', 'POS_TAG': 'NOUN'}
# {'ID': '2', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '3', 'WORD': 'pICe', 'POS_TAG': 'ADP'}
# {'ID': '4', 'WORD': 'pawWaroM', 'POS_TAG': 'NOUN'}
# {'ID': '5', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '6', 'WORD': 'Dera', 'POS_TAG': 'NOUN'}
# {'ID': '7', 'WORD': 'ke', 'POS_TAG': 'ADP'}
# {'ID': '8', 'WORD': 'pAsa', 'POS_TAG': 'ADP'}
# {'ID': '9', 'WORD': 'BagavAna', 'POS_TAG': 'NOUN'}
# {'ID': '10', 'WORD': 'ISAna', 'POS_TAG': 'PROPN'}
# {'ID': '11', 'WORD': 'kA', 'POS_TAG': 'ADP'}
# {'ID': '12', 'WORD': 'maMxira', 'POS_TAG': 'NOUN'}
# {'ID': '13', 'WORD': 'hE', 'POS_TAG': 'AUX'}
# {'ID': '14', 'WORD': '.', 'POS_TAG': 'PUNCT'}

# %%
all_train_sent = []
all_train_tags = []
temp_sent_train = []
temp_tags_train = []
for i in range(len(train_sents[0])):
    if train_sents[0][i]['ID']=='1':
        all_train_sent.append(temp_sent_train)
        all_train_tags.append(temp_tags_train)
        temp_sent_train = []
        temp_tags_train = []
        temp_sent_train.append(train_sents[0][i]['WORD'])
        temp_tags_train.append(train_sents[0][i]['POS_TAG'])
    else:
        temp_sent_train.append(train_sents[0][i]['WORD'])
        temp_tags_train.append(train_sents[0][i]['POS_TAG'])
    
all_train_sent = [ele for ele in all_train_sent if ele != ['WORD']] 
all_train_tags = [ele for ele in all_train_tags if ele != ['POS_TAG']]

all_test_sent = []
all_test_tags = []
temp_sent_test = []
temp_tags_test = []
for i in range(len(test_sents[0])):
    if test_sents[0][i]['ID']=='1':
        all_test_sent.append(temp_sent_test)
        all_test_tags.append(temp_tags_test)
        temp_sent_test = []
        temp_tags_test = []
        temp_sent_test.append(test_sents[0][i]['WORD'])
        temp_tags_test.append(test_sents[0][i]['POS_TAG'])
    else:
        temp_sent_test.append(test_sents[0][i]['WORD'])
        temp_tags_test.append(test_sents[0][i]['POS_TAG'])
    
all_test_sent = [ele for ele in all_test_sent if ele != ['WORD']] 
all_test_tags = [ele for ele in all_test_tags if ele != ['POS_TAG']]

train = []
test = []
for i in range(len(all_train_sent)):
    temp_list_train = []
    for j in range(len(all_train_sent[i])):
        temp_list_train.append((all_train_sent[i][j], all_train_tags[i][j]))
    train.append(temp_list_train)
    
for i in range(len(all_test_sent)):
    temp_list_test = []
    for j in range(len(all_test_sent[i])):
        temp_list_test.append((all_test_sent[i][j], all_test_tags[i][j]))
    test.append(temp_list_test)

print('\nTrain\n')
print(train)
print('\nTest\n')
print(test)
# Out:
# Train
#
# [[('yaha', 'DET'), ('eSiyA', 'PROPN'), ('kI', 'ADP'), ('sabase', 'ADV'), ('badZI', 'ADJ'), ('masjixoM', 'NOUN'), ('meM', 'ADP'), ('se', 'ADP'), ('eka', 'NUM'), ('hE', 'AUX'), ('.', 'PUNCT')], [('ise', 'PRON'), ('navAba', 'NOUN'), ('SAhajehana', 'PROPN'), ('ne', 'ADP'), ('banavAyA', 'VERB'), ('WA', 'AUX'), ('.', 'PUNCT')], [('isakA', 'PRON'), ('praveSa', 'NOUN'), ('xvAra', 'NOUN'), ('xo', 'NUM'), ('maMjilA', 'ADJ'), ('hE', 'AUX'), ('.', 'PUNCT')], [('jisameM', 'PRON'), ('cAra', 'NUM'), ('meharAbeM', 'NOUN'), ('hEM', 'AUX'), ('Ora', 'CCONJ'), ('muKya', 'ADJ'), ('prArWanA', 'NOUN'), ('hOYla', 'NOUN'), ('meM', 'ADP'), ('jAne', 'VERB'), ('ke', 'ADP'), ('lie', 'ADP'), ('9', 'NUM'), ('praveSa', 'NOUN'), ('xvAra', 'NOUN'), ('hEM', 'VERB'), ('.', 'PUNCT')], [('pUrI', 'ADJ'), ('imArawa', 'NOUN'), ('behaxa', 'ADV'), ('KUbasUrawa', 'ADJ'), ('hE', 'AUX'), ('.', 'PUNCT')], [('yahAz', 'PRON'), ('lagane', 'VERB'), ('vAlA', 'ADP'), ('wIna', 'NUM'), ('xina', 'NOUN'), ('kA', 'ADP'), ('ijwimA', 'NOUN'), ('pUre', 'ADJ'), ('xeSa', 'NOUN'), ('ke', 'ADP'), ('logoM', 'NOUN'), ('ko', 'ADP'), ('AmaMwriwa', 'ADJ'), ('karawA', 'VERB'), ('hE', 'AUX'), ('.', 'PUNCT')], [('SOkawa', 'PROPN'), ('mahala', 'PROPN'), ('ke', 'ADP'), ('sAmane', 'ADP'), ('badZI', 'ADJ'), ('JIla', 'NOUN'), ('ke', 'ADP'), ('kinAre', 'NOUN'), ('sWiwa', 'ADJ'), ('vAswukalA', 'NOUN'), ('kA', 'ADP'), ('yaha', 'DET'), ('KUbasUrawa', 'ADJ'), ('namUnA', 'NOUN'), ('kuxasiyA', 'PROPN'), ('begama', 'PROPN'), ('ke', 'ADP'), ('kAla', 'NOUN'), ('kA', 'ADP'), ('hE', 'AUX'), ('jinheM', 'PRON'), ('gohara', 'PROPN'), ('begama', 'PROPN'), ('BI', 'PART'), ('kahA', 'VERB'), ('jAwA', 'AUX'), ('WA', 'AUX'), ('.', 'PUNCT')], [('yaha', 'PRON'), ('hiMxU', 'NOUN'), ('Ora', 'CCONJ'), ('mugala', 'NOUN'), ('kalA', 'NOUN'), ('kA', 'ADP'), ('axBuwa', 'ADJ'), ('saMgama', 'NOUN'), ('hE', 'AUX'), ('.', 'PUNCT')], [('yaha', 'PRON'), ('BArawa', 'PROPN'), ('kI', 'ADP'), ('anUTI', 'ADJ'), ('rARtrIya', 'ADJ'), ('saMsWA', 'NOUN'), ('hE', 'AUX'), ('.', 'PUNCT')], [('muKya', 'ADJ'), ('rUpa', 'NOUN'), ('se', 'ADP'), ('yaha', 'PRON'), ('praxarSana', 'NOUN'), ('kalA', 'NOUN'), ('Ora', 'CCONJ'), ('xqSya', 'NOUN'), ('kalA', 'NOUN'), ('kA', 'ADP'), ('keMxra', 'NOUN'), ('hE', 'AUX'), ('.', 'PUNCT')], [('ise', 'PRON'), ('cArlsa', 'NOUN'), ('koriyA', 'PROPN'), ('ne', 'ADP'), ('dijAina', 'NOUN'), ('kiyA', 'VERB'), ('hE', 'AUX'), ('.', 'PUNCT')], [('viSAla', 'ADJ'), ('kRewra', 'NOUN'), ('meM', 'ADP'), ('PEle', 'VERB'), ('isa', 'DET'), ('Bavana', 'NOUN'), ('ke', 'ADP'), ('Asa', 'NOUN'), ('-', 'PUNCT'), ('pAsa', 'ADP'), ('kA', 'ADP'), ('prAkqwika', 'ADJ'), ('sOMxarya', 'NOUN'), ('ise', 'PRON'), ('Ora', 'DET'), ('BI', 'PART'), ('Bavya', 'ADJ'), ('banAwA', 'VERB'), ('hE', 'AUX'), ('.', 'PUNCT')], [('yahIM', 'PRON'), ('para', 'ADP'), ('eka', 'NUM'), ('kalA', 'NOUN'), ('saMgrahAlaya', 'NOUN'), (',', 'PUNCT'), ('kalA', 'NOUN'), ('xIrGA', 'NOUN'), (',', 'PUNCT'), ('PAina', 'NOUN'), ('Arta', 'NOUN'), ('ke', 'ADP'), ('lie', 'ADP'), ('kAryaSAlA', 'NOUN'), (',', 'PUNCT'), ('eka', 'NUM'), ('Wietara', 'NOUN'), (',', 'PUNCT'), ('aMwaraMga', 'ADJ'), ('Ora', 'CCONJ'), ('bahiraMga', 'ADJ'), ('OYditoriyama', 'NOUN'), (',', 'PUNCT'), ('riharsala', 'NOUN'), ('kakRa', 'NOUN'), (',', 'PUNCT'), ('BArawIya', 'ADJ'), ('kaviwAoM', 'NOUN'), ('kA', 'ADP'), ('puswakAlaya', 'NOUN'), (',', 'PUNCT'), ('SAswrIya', 'ADJ'), ('Ora', 'CCONJ'), ('loka', 'ADJ'), ('saMgIwa', 'NOUN'), ('saMgrahAlaya', 'NOUN'), ('BI', 'PART'), ('hEM', 'AUX'), ('.', 'PUNCT')], [('yaha', 'PRON'), ('somavAra', 'PROPN'), ('ke', 'ADP'), ('alAvA', 'ADP'), ('pUre', 'ADJ'), ('sapwAha', 'NOUN'), ('xopahara', 'NOUN'), ('2', 'NUM'), ('baje', 'NOUN'), ('se', 'ADP'), ('rAwa', 'NOUN'), ('8', 'NUM'), ('baje', 'NOUN'), ('waka', 'ADP'), ('KulA', 'VERB'), ('rahawA', 'AUX'), ('hE', 'AUX'), ('.', 'PUNCT')], [('yaha', 'PRON'), ('eka', 'NUM'), ('anUTA', 'ADJ'), ('saMgrahAlaya', 'NOUN'), ('hE', 'AUX'), ('jo', 'PRON'), ('200', 'NUM'), ('ekadZa', 'NOUN'), ('meM', 'ADP'), ('SyAmalA', 'PROPN'), ('hilsa', 'PROPN'), ('para' ...
#
# Test
#
# [[('rAmAyaNa', 'PROPN'), ('kAla', 'PROPN'), ('meM', 'ADP'), ('BagavAna', 'NOUN'), ('rAma', 'PROPN'), ('ke', 'ADP'), ('puwra', 'NOUN'), ('kuSa', 'PROPN'), ('kI', 'ADP'), ('rAjaXAnI', 'NOUN'), ('kuSAvawI', 'PROPN'), ('ko', 'ADP'), ('483', 'PROPN'), ('IsA', 'PROPN'), ('pUrva', 'PROPN'), ('buxXa', 'PROPN'), ('ne', 'ADP'), ('apane', 'PRON'), ('aMwima', 'ADJ'), ('viSrAma', 'NOUN'), ('ke', 'ADP'), ('lie', 'ADP'), ('cunA', 'VERB'), ('.', 'PUNCT')], [('malloM', 'NOUN'), ('kI', 'ADP'), ('rAjaXAnI', 'NOUN'), ('hone', 'VERB'), ('ke', 'ADP'), ('kAraNa', 'ADP'), ('prAcInakAla', 'NOUN'), ('meM', 'ADP'), ('isa', 'DET'), ('sWAna', 'NOUN'), ('kA', 'ADP'), ('awyaMwa', 'ADJ'), ('mahawva', 'NOUN'), ('WA', 'VERB'), ('.', 'PUNCT')], [('bOxXa', 'PROPN'), ('XarmAvalaMbiyoM', 'NOUN'), ('ke', 'ADP'), ('anusAra', 'ADP'), ('luMbanI', 'PROPN'), ('","', 'PUNCT'), ('boXagayA', 'PROPN'), ('Ora', 'CCONJ'), ('sAranAWa', 'PROPN'), ('ke', 'ADP'), ('sAWa', 'ADP'), ('hI', 'PART'), ('isa', 'DET'), ('sWAna', 'NOUN'), ('kA', 'ADP'), ('viSax', 'ADJ'), ('mahawva', 'NOUN'), ('hE', 'AUX'), ('.', 'PUNCT')], [('hiMxU', 'ADJ'), ('rAjAoM', 'NOUN'), ('ke', 'ADP'), ('kAla', 'NOUN'), ('meM', 'ADP'), ('cIna', 'PROPN'), ('se', 'ADP'), ('hvena', 'PROPN'), ('sAMga', 'PROPN'), ('","', 'PUNCT'), ('PAhyAna', 'PROPN'), ('Ora', 'CCONJ'), ('iwsiMga', 'PROPN'), ('ne', 'ADP'), ('apane', 'PRON'), ('yAwrA', 'NOUN'), ('vqwwAMwa', 'NOUN'), ('meM', 'ADP'), ('isa', 'DET'), ('sWAna', 'NOUN'), ('ke', 'ADP'), ('gOrava', 'NOUN'), ('kA', 'ADP'), ('varNana', 'NOUN'), ('kiyA', 'VERB'), ('hE', 'AUX'), ('.', 'PUNCT')], [('kuSInagara', 'PROPN'), ('kA', 'ADP'), ('sabase', 'ADV'), ('jyAxA', 'DET'), ('mahawva', 'NOUN'), ('bOxXa', 'PROPN'), ('wIrWa', 'NOUN'), ('ke', 'ADP'), ('rUpa', 'ADP'), ('meM', 'ADP'), ('hE', 'AUX'), ('.', 'PUNCT')], [('1876', 'PROPN'), ('meM', 'ADP'), ('yaha', 'DET'), ('sWAna', 'NOUN'), ('eka', 'NUM'), ('bAra', 'NOUN'), ('Pira', 'ADV'), ('prakASa', 'NOUN'), ('meM', 'ADP'), ('AyA', 'VERB'), ('","', 'PUNCT'), ('jaba', 'PRON'), ('wawkAlIna', 'ADJ'), ('purAwawvavewwA', 'NOUN'), ('lOYrda', 'NOUN'), ('karniMGama', 'PROPN'), ('ne', 'ADP'), ('mahAparinirvANa', 'PROPN'), ('mUrwi', 'PROPN'), ('kI', 'ADP'), ('Koja', 'NOUN'), ('kI', 'VERB'), ('.', 'PUNCT')], [('Aie', 'VERB'), ('kareM', 'VERB'), ('sEra', 'NOUN'), ('-', 'PUNCT')], [('kuSInagara', 'PROPN'), ('kI', 'ADP'), ('sImA', 'NOUN'), ('meM', 'ADP'), ('praveSa', 'NOUN'), ('karawe', 'VERB'), ('hI', 'PART'), ('Bavya', 'ADJ'), ('praveSaxvAra', 'NOUN'), ('ApakA', 'PRON'), ('svAgawa', 'NOUN'), ('karawA', 'VERB'), ('hE', 'AUX'), ('.', 'PUNCT')], [('isake', 'PRON'), ('bAxa', 'ADP'), ('Ama', 'ADJ'), ('wOra', 'NOUN'), ('para', 'ADP'), ('paryatakoM', 'NOUN'), ('kI', 'ADP'), ('nigAha', 'NOUN'), ('mahAparinirvANa', 'PROPN'), ('maMxira', 'PROPN'), ('kI', 'ADP'), ('ora', 'ADP'), ('padZawI', 'VERB'), ('hE', 'AUX'), ('.', 'PUNCT')], [('kuSInagara', 'PROPN'), ('kA', 'ADP'), ('mahawva', 'NOUN'), ('mahAparinirvANa', 'PROPN'), ('maMxira', 'PROPN'), ('se', 'ADP'), ('hE', 'AUX'), ('.', 'PUNCT')], [('isa', 'DET'), ('maMxira', 'NOUN'), ('kA', 'ADP'), ('sWApawya', 'NOUN'), ('ajaMwA', 'PROPN'), ('kI', 'ADP'), ('guPAoM', 'NOUN'), ('se', 'ADP'), ('preriwa', 'ADJ'), ('hE', 'AUX'), ('.', 'PUNCT')], [('maMxira', 'NOUN'), ('ke', 'ADP'), ('dAta', 'NOUN'), ('hUbahU', 'ADV'), ('ajaMwA', 'PROPN'), ('kI', 'ADP'), ('guPAoM', 'NOUN'), ('ke', 'ADP'), ('dAta', 'NOUN'), ('kI', 'ADP'), ('waraha', 'ADP'), ('hEM', 'AUX'), ('.', 'PUNCT')], [('yaha', 'DET'), ('maMxira', 'NOUN'), ('usI', 'DET'), ('sWAna', 'NOUN'), ('para', 'ADP'), ('banAyA', 'VERB'), ('gayA', 'AUX'), ('hE', 'AUX'), ('","', 'PUNCT'), ('jahAz', 'PRON'), ('se', 'ADP'), ('yaha', 'DET'), ('mUrwi', 'NOUN'), ('nikAlI', 'VERB'), ('gaI', 'AUX'), ('WI', 'AUX'), ('.', 'PUNCT')], [('maMxira', 'NOUN'), ('ke', 'ADP'), ('pUrva', 'ADJ'), ('hisse', 'NOUN'), ('meM', 'ADP'), ('eka', 'NUM'), ('swUpa', 'NOUN'), ('hE', 'AUX'), ('.', 'PUNCT')], [('yahAz', 'PRON'), ('para', 'ADP'), ('BagavAna', 'NOUN'), ('buxXa', 'PROPN'), ('kA', 'ADP'), ('aMwima', 'AD ...

# %%
def case_of_chars(s):
    l,u = 0,0
    for i in s: 
        if (i>='a'and i<='z'): 
            l=l+1                  #counting lower case 
        if (i>='A'and i<='Z'): 
            u=u+1                  #counting upper case 
    return l, u

# %%
def word2features(sent, i):
    word = sent[i][0]

    features = {
        'length': len(word),
        'no. of lower case chars': case_of_chars(word)[0],
        'no. of upper case chars': case_of_chars(word)[1],
        'word[-1:]': word[-1:],
        'word[-2:]': word[-2:],
        'word[-3:]': word[-3:],
        'word[:3]': word[:3],
        'word[:2]': word[:2],
        'word[:1]': word[:1],
        'word.isalnum': word.isalnum(),
        'word.islower()': word.islower(),
        'word.isupper()': word.isupper(),
        'word.isdigit()': word.isdigit(),
    }
    if i > 0:
        word1 = sent[i-1][0]
        features.update({
            '-1:word': word1,
            '-1:length' : len(word1),
        })
    else:
        features['BOS'] = True

    if i < len(sent)-1:
        word1 = sent[i+1][0]
        features.update({
            '+1:word': word1,
            '+1:length': len(word1),
        })
    else:
        features['EOS'] = True

    return features


def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [postag for token, postag in sent]

# %% [markdown]
# ## Features used :
# 1) current word's length : since longer words usually turn out to be proper nouns and shorter words are usually conjunctions or determinants
# <br>
# 2) no. of upper and lower case chars : the letters that are capitalised are usually pronounced differently; for example, A is pronounced as aa and a is pronounced as a, so it brings the pronounciation into account
# <br>
# 3) suffix : the suffix might decide if a word is a verb
# <br>
# 4) prefix : the prefix might decide if a word is a noun
# <br>
# 5) if word is alphanumeric : if it's not alpha numeric, then the word automatically becomes a punctuation
# <br>
# 6) case of the word : upper case words are usually proper nouns or exclamations
# <br>
# 7) numbers : will decide if the word gets a POS tag apart from X
# <br>
# 8) previous word : previous word will contribute to subject verb agreement and influence the POS tag of current word
# <br>
# 9) previous word length : length will help in determining it's POS which might direct current word's POS due to subject verb agreement
# <br>
# 10) next word : will contribute to subject verb agreement and influence current word's POS
# <br>
# 11) next word's length : will aid in determining current word's POS through it's own POS tag
# <br>

# %%
X_train = [sent2features(s) for s in train]
y_train = [sent2labels(s) for s in train]

X_test = [sent2features(s) for s in test]
y_test = [sent2labels(s) for s in test]

# %%
labels = []
for i in range(len(y_train)):
    for j in range(len(y_train[i])):
        if y_train[i][j] not in labels:
            labels.append(y_train[i][j])
labels
# Out:
# ['DET',
#  'PROPN',
#  'ADP',
#  'ADV',
#  'ADJ',
#  'NOUN',
#  'NUM',
#  'AUX',
#  'PUNCT',
#  'PRON',
#  'VERB',
#  'CCONJ',
#  'PART',
#  'SCONJ',
#  'X']

# %%
# define fixed parameters and parameters to search
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    max_iterations=100,
    all_possible_transitions=True
)
params_space = {
    'c1': scipy.stats.expon(scale=0.5),
    'c2': scipy.stats.expon(scale=0.05),
}

# use the same metric for evaluation
f1_scorer = make_scorer(metrics.flat_f1_score,
                        average='weighted', labels=labels)

# search
rs = RandomizedSearchCV(crf, params_space,
                        cv=3,
                        verbose=1,
                        n_jobs=-1,
                        n_iter=50,
                        scoring=f1_scorer)
rs.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed:   25.1s finished
# RandomizedSearchCV(cv=3,
#                    estimator=CRF(algorithm='lbfgs',
#                                  all_possible_transitions=True,
#                                  keep_tempfiles=None, max_iterations=100),
#                    n_iter=50, n_jobs=-1,
#                    param_distributions={'c1': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001C09ABFCEB0>,
#                                         'c2': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001C09ABF57C0>},
#                    scoring=make_scorer(flat_f1_score, average=weighted, labels=['DET', 'PROPN', 'ADP', 'ADV', 'ADJ', 'NOUN', 'NUM', 'AUX', 'PUNCT', 'PRON', 'VERB', 'CCONJ', 'PART', 'SCONJ', 'X']),
#                    verbose=1)

# %%
# crf = rs.best_estimator_
print('best params:', rs.best_params_)
print('best CV score:', rs.best_score_)
print('model size: {:0.2f}M'.format(rs.best_estimator_.size_ / 1000000))
# Out:
# best params: {'c1': 0.017577430869692427, 'c2': 0.026644033992842625}
# best CV score: 0.8543221649215033
# model size: 0.39M

# %%
sorted_labels = sorted(labels, key=lambda name: (name[1:], name[0]))

crf = rs.best_estimator_

y_pred_test = crf.predict(X_test)
print('\n For test set :\n')
print(metrics.flat_classification_report(y_test, y_pred_test, labels=sorted_labels, digits=3))

y_pred_train = crf.predict(X_train)
print('\n For training set :\n')
print(metrics.flat_classification_report(y_train, y_pred_train, labels=sorted_labels, digits=3))
# Out:
#  For test set :
#
#               precision    recall  f1-score   support
#
#            X      0.000     0.000     0.000         0
#         PART      0.969     0.939     0.954        33
#        CCONJ      1.000     1.000     1.000        25
#        SCONJ      0.667     0.667     0.667         3
#          ADJ      0.650     0.691     0.670        94
#          ADP      0.967     0.970     0.969       303
#          ADV      0.692     0.429     0.529        21
#         VERB      0.878     0.869     0.873        99
#          DET      0.821     0.889     0.853        36
#         NOUN      0.792     0.846     0.818       324
#         PRON      0.848     0.862     0.855        65
#        PROPN      0.598     0.549     0.572       144
#          NUM      0.889     0.960     0.923        25
#        PUNCT      1.000     0.910     0.953       134
#          AUX      0.956     0.949     0.953       138
#
#    micro avg      0.852     0.852     0.852      1444
#    macro avg      0.782     0.769     0.773      1444
# weighted avg      0.852     0.852     0.851      1444
#
#
#  For training set :
#
#               precision    recall  f1-score   support
#
#            X      1.000     1.000     1.000         2
#         PART      1.000     1.000     1.000       163
#        CCONJ      1.000     1.000     1.000       150
#        SCONJ      1.000     1.000     1.000        61
#          ADJ      1.000     1.000     1.000       569
#          ADP      0.999     1.000     1.000      1384
#          ADV      1.000     0.991     0.995       110
#         VERB      1.000     0.992     0.996       639
#          DET      1.000     1.000     1.000       230
#         NOUN      1.000     1.000     1.000      1596
#         PRON      1.000     1.000     1.000       430
#        PROPN      1.000     1.000     1.000       707
#          NUM      1.000     1.000     1.000       152
#        PUNCT      1.000     1.000     1.000       677
#          AUX      0.993     1.000     0.997       728
#
#     accuracy                          0.999      7598
#    macro avg      0.999     0.999     0.999      7598
# weighted avg      0.999     0.999     0.999      7598

# %%
from collections import Counter

def print_transitions(trans_features):
    for (label_from, label_to), weight in trans_features:
        print("%-6s -> %-7s %0.6f" % (label_from, label_to, weight))

print("Top likely transitions:")
print_transitions(Counter(crf.transition_features_).most_common(10))

print("\nTop unlikely transitions:")
print_transitions(Counter(crf.transition_features_).most_common()[-10:])
# Out:
# Top likely transitions:
# VERB   -> AUX     4.340922
# PROPN  -> PROPN   2.849597
# PART   -> NUM     2.450484
# AUX    -> AUX     2.326650
# NUM    -> NOUN    2.230064
# PRON   -> ADP     2.202250
# ADJ    -> NOUN    2.148174
# DET    -> NOUN    1.863635
# DET    -> PART    1.685775
# NOUN   -> ADP     1.536293
#
# Top unlikely transitions:
# ADV    -> AUX     -1.946852
# PROPN  -> PART    -2.044627
# PROPN  -> DET     -2.100459
# NUM    -> PROPN   -2.140155
# CCONJ  -> AUX     -2.151830
# CCONJ  -> PART    -2.219615
# PROPN  -> AUX     -2.664885
# DET    -> ADP     -3.285730
# ADJ    -> PRON    -3.711961
# ADJ    -> ADP     -4.240564
